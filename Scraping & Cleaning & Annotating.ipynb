# %% [markdown]
# ### Web Scraping 1: Get the top20 songs list of Coldplay on Spotify from a website called KWORB
# Kworb is a music data analytics website that aggregates and showcases Spotify streaming charts and artist rankings. The platform offers insights into song popularity and trends across various regions globally.

# %%
import pandas as pd
import requests

# URL of kworb
url = "https://kworb.net/spotify/artist/4gzpq5DPGxSnKTe4SA8HAU_songs.html"
# request the content
r = requests.get(url)
# make sure the request is success
if r.status_code == 200:
    # analyze the tables on the website
    df_list = pd.read_html(r.text)
    #get the second table on the website
    df = df_list[1]
    #remove the repeated row...
    df = df.drop(13, axis=0)
    # save the table as CSV format
    df.to_csv("spotify_songs.csv", index=False)
    print(df.head(20))
# Out:
#                        Song Title     Streams      Daily
# 0      * Something Just Like This  2360429097  1024226.0
# 1                          Yellow  1994170156  1619221.0
# 2                    Viva La Vida  1817301965  1397710.0
# 3                   The Scientist  1730247039   809670.0
# 4                         Fix You  1331066416   726609.0
# 5             A Sky Full of Stars  1306202500   927520.0
# 6            Hymn for the Weekend  1269746647   634085.0
# 7                     My Universe  1165484041   599792.0
# 8                        Paradise  1162178312   653060.0
# 9         Adventure of a Lifetime   923446921   532144.0
# 10                         Clocks   793528827   576293.0
# 11                         Sparks   771267093  1062281.0
# 12                          Magic   669899679   157968.0
# 14                        Trouble   329969893   160220.0
# 15                   Higher Power   320956467   153495.0
# 16                    In My Place   300647715   193981.0
# 17               Christmas Lights   296139143  1070425.0
# 18  Every Teardrop Is a Waterfall   284987603   117416.0
# 19                       Everglow   279301002    82641.0
# 20              Princess of China   259481112    96931.0

# %% [markdown]
# ### Web Scraping 2: Get the lyrics of top20 songs from the website Lyricsfreak

# %%
import requests
from bs4 import BeautifulSoup

# Create the name list of top20 songs
songs = df['Song Title'].head(20).tolist()

# The website we are gong to visit
base_url = 'https://www.lyricsfreak.com/search.php?q='

# Create request
with requests.Session() as s:
    for song in songs:
        # Construct a URL that conforms to the website's search format
        search_url = base_url + "+".join(song.split())

        # Scrape the URL of the lyrics page from the search results
        search_response = s.get(search_url)
        if search_response.ok:
            search_soup = BeautifulSoup(search_response.text, "html.parser")

            # Find the lyrics link
            search_result = search_soup.find('a', attrs={'class': 'song'})
            if search_result:
                lyrics_url = search_result.get('href')

                # request for the lyrics page
                lyrics_full_url = 'https://www.lyricsfreak.com' + lyrics_url
                lyrics_response = s.get(lyrics_full_url)
                if lyrics_response.ok:

                    # analyze lyrics pages
                    lyrics_soup = BeautifulSoup(lyrics_response.text, "html.parser")              

                    # identify the container that holds the lyrics based on the webpage structure
                    lyrics_div = lyrics_soup.find('div', id="content")
                    if lyrics_div:
                        lyrics = lyrics_div.get_text(strip=True)

                        # clean the title of song
                        safe_song_title = "".join([c for c in song if c.isalpha() or c.isdigit() or c==' ']).rstrip()

                        # save the lyrics as TXT format
                        with open(f"{safe_song_title}.txt", "w", encoding="utf-8") as file:
                            file.write(lyrics)
                    else:
                        print(f"Could not find the lyrics container for {song}.")
                else:
                    print(f"Failed to retrieve lyrics page for {song}")
            else:
                print(f"Could not find a lyrics link in search results for {song}.")
        else:
            print(f"Failed to retrieve search page for {song}")

# %% [markdown]
# ###  Cleaning & Annotating

# %% [markdown]
# #### 1. Install and initiate everything we are going to use

# %%
pip install nltk
# Out:
# Requirement already satisfied: nltk in /Users/irontree/anaconda3/lib/python3.10/site-packages (3.7)
# Requirement already satisfied: regex>=2021.8.3 in /Users/irontree/anaconda3/lib/python3.10/site-packages (from nltk) (2022.7.9)
# Requirement already satisfied: joblib in /Users/irontree/anaconda3/lib/python3.10/site-packages (from nltk) (1.1.1)
# Requirement already satisfied: tqdm in /Users/irontree/anaconda3/lib/python3.10/site-packages (from nltk) (4.64.1)
# Requirement already satisfied: click in /Users/irontree/anaconda3/lib/python3.10/site-packages (from nltk) (8.0.4)
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install spacy
# Out:
# Requirement already satisfied: spacy in /Users/irontree/anaconda3/lib/python3.10/site-packages (3.7.2)
# Requirement already satisfied: spacy-legacy<3.1.0,>=3.0.11 in /Users/irontree/anaconda3/lib/python3.10/site-packages (from spacy) (3.0.12)
# Requirement already satisfied: srsly<3.0.0,>=2.4.3 in /Users/irontree/anaconda3/lib/python3.10/site-packages (from spacy) (2.4.8)
# Requirement already satisfied: catalogue<2.1.0,>=2.0.6 in /Users/irontree/anaconda3/lib/python3.10/site-packages (from spacy) (2.0.10)
# Requirement already satisfied: typer<0.10.0,>=0.3.0 in /Users/irontree/anaconda3/lib/python3.10/site-packages (from spacy) (0.9.0)
# Requirement already satisfied: smart-open<7.0.0,>=5.2.1 in /Users/irontree/anaconda3/lib/python3.10/site-packages (from spacy) (5.2.1)
# Requirement already satisfied: preshed<3.1.0,>=3.0.2 in /Users/irontree/anaconda3/lib/python3.10/site-packages (from spacy) (3.0.9)
# Requirement already satisfied: langcodes<4.0.0,>=3.2.0 in /Users/irontree/anaconda3/lib/python3.10/site-packages (from spacy) (3.3.0)
# Requirement already satisfied: spacy-loggers<2.0.0,>=1.0.0 in /Users/irontree/anaconda3/lib/python3.10/site-packages (from spacy) (1.0.5)
# Requirement already satisfied: thinc<8.3.0,>=8.1.8 in /Users/irontree/anaconda3/lib/python3.10/site-packages (from spacy) (8.2.1)
# Requirement already satisfied: requests<3.0.0,>=2.13.0 in /Users/irontree/anaconda3/lib/python3.10/site-packages (from spacy) (2.28.1)
# Requirement already satisfied: packaging>=20.0 in /Users/irontree/anaconda3/lib/python3.10/site-packages (from spacy) (22.0)
# Requirement already satisfied: pydantic!=1.8,!=1.8.1,<3.0.0,>=1.7.4 in /Users/irontree/anaconda3/lib/python3.10/site-packages (from spacy) (2.5.2)
# Requirement already satisfied: murmurhash<1.1.0,>=0.28.0 in /Users/irontree/anaconda3/lib/python3.10/site-packages (from spacy) (1.0.10)
# Requirement already satisfied: weasel<0.4.0,>=0.1.0 in /Users/irontree/anaconda3/lib/python3.10/site-packages (from spacy) (0.3.4)
# Requirement already satisfied: numpy>=1.19.0 in /Users/irontree/anaconda3/lib/python3.10/site-packages (from spacy) (1.23.5)
# Requirement already satisfied: wasabi<1.2.0,>=0.9.1 in /Users/irontree/anaconda3/lib/python3.10/site-packages (from spacy) (1.1.2)
# Requirement already satisfied: jinja2 in /Users/irontree/anaconda3/lib/python3.10/site-packages (from spacy) (3.1.2)
# Requirement already satisfied: tqdm<5.0.0,>=4.38.0 in /Users/irontree/anaconda3/lib/python3.10/site-packages (from spacy) (4.64.1)
# Requirement already satisfied: setuptools in /Users/irontree/anaconda3/lib/python3.10/site-packages (from spacy) (65.6.3)
# Requirement already satisfied: cymem<2.1.0,>=2.0.2 in /Users/irontree/anaconda3/lib/python3.10/site-packages (from spacy) (2.0.8)
# Requirement already satisfied: annotated-types>=0.4.0 in /Users/irontree/anaconda3/lib/python3.10/site-packages (from pydantic!=1.8,!=1.8.1,<3.0.0,>=1.7.4->spacy) (0.6.0)
# Requirement already satisfied: pydantic-core==2.14.5 in /Users/irontree/anaconda3/lib/python3.10/site-packages (from pydantic!=1.8,!=1.8.1,<3.0.0,>=1.7.4->spacy) (2.14.5)
# Requirement already satisfied: typing-extensions>=4.6.1 in /Users/irontree/anaconda3/lib/python3.10/site-packages (from pydantic!=1.8,!=1.8.1,<3.0.0,>=1.7.4->spacy) (4.9.0)
# Requirement already satisfied: idna<4,>=2.5 in /Users/irontree/anaconda3/lib/python3.10/site-packages (from requests<3.0.0,>=2.13.0->spacy) (3.4)
# Requirement already satisfied: charset-normalizer<3,>=2 in /Users/irontree/anaconda3/lib/python3.10/site-packages (from requests<3.0.0,>=2.13.0->spacy) (2.0.4)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /Users/irontree/anaconda3/lib/python3.10/site-packages (from requests<3.0.0,>=2.13.0->spacy) (1.26.14)
# Requirement already satisfied: certifi>=2017.4.17 in /Users/irontree/anaconda3/lib/python3.10/site-packages (from requests<3.0.0,>=2.13.0->spacy) (2023.7.22)
# Requirement already satisfied: blis<0.8.0,>=0.7.8 in /Users/irontree/anaconda3/lib/python3.10/site-packages (from thinc<8.3.0,>=8.1.8->spacy) (0.7.11)
# Requirement already satisfied: confection<1.0.0,>=0.0.1 in /Users/irontree/anaconda3/lib/python3.10/site-packages (from thinc<8.3.0,>=8.1.8->spacy) (0.1.4)
# Requirement already satisfied: click<9.0.0,>=7.1.1 in /Users/irontree/anaconda3/lib/python3.10/site-packages (from typer<0.10.0,>=0.3.0->spacy) (8.0.4)
# Requirement already satisfied: cloudpathlib<0.17.0,>=0.7.0 in /Users/irontree/anaconda3/lib/python3.10/site-packages (from weasel<0.4.0,>=0.1.0->spacy) (0.16.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /Users/irontree/anaconda3/lib/python3.10/site-packages (from jinja2->spacy) (2.1.1)
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install pandas
# Out:
# Requirement already satisfied: pandas in /Users/irontree/anaconda3/lib/python3.10/site-packages (1.5.3)
# Requirement already satisfied: python-dateutil>=2.8.1 in /Users/irontree/anaconda3/lib/python3.10/site-packages (from pandas) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /Users/irontree/anaconda3/lib/python3.10/site-packages (from pandas) (2022.7)
# Requirement already satisfied: numpy>=1.21.0 in /Users/irontree/anaconda3/lib/python3.10/site-packages (from pandas) (1.23.5)
# Requirement already satisfied: six>=1.5 in /Users/irontree/anaconda3/lib/python3.10/site-packages (from python-dateutil>=2.8.1->pandas) (1.16.0)
# Note: you may need to restart the kernel to use updated packages.

# %%
# initiate everything
import os
import re
import string
import pandas as pd
import nltk
from nltk.corpus import stopwords
import spacy

nltk.download('stopwords')
nltk.download('punkt')
stop_words = set(stopwords.words('english'))
spacy_nlp = spacy.load('en_core_web_sm')
# Out:
# [nltk_data] Downloading package stopwords to
# [nltk_data]     /Users/irontree/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# [nltk_data] Downloading package punkt to /Users/irontree/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!

# %% [markdown]
# #### 2. Define the function for cleaning the texts

# %%
def clean_lyrics(text):
    # remove the content in []
    text = re.sub(r'\\\[.\*?\\]', '', text)
    # lowercasing
    text = text.lower()
    # remove punctuation
    text = text.translate(str.maketrans('', '', string.punctuation))
    # Tokenization and remove stop words
    tokens = nltk.word_tokenize(text)
    # remove stopwords
    tokens = [word for word in tokens if word not in stop_words]
    return tokens

# %% [markdown]
# #### 3. Define the function for getting POS and Lemmas

# %%
def get_pos_and_lemma(tokens):
    spacy_doc = spacy_nlp(' '.join(tokens))
    # get pos
    pos = [token.pos_ for token in spacy_doc]
    # get lemmas 
    lemmas = [token.lemma_ for token in spacy_doc]
    return pos, lemmas

# %% [markdown]
# #### 4. Read the text files and make them into structured dataset

# %%
file_data = []
# read the text
for filename in os.listdir('Lyrics Dataset of top20 Songs'):
    if filename.endswith('.txt'):
        with open(f'Lyrics Dataset of top20 Songs/{filename}', 'r', encoding='utf-8') as file:
            text = file.read()
            #clean the text
            cleaned_tokens = clean_lyrics(text)
            #get pos and lemmas of the text
            pos_tags, lemmas = get_pos_and_lemma(cleaned_tokens)
            #remove the extension name of file 
            file_data.append({
                'filename': filename.replace('.txt', ''),
                'original_text': text,
                'tokens': cleaned_tokens,
                'POS': pos_tags,
                'lemmas': lemmas
            })
file_data
# Out:
# [{'filename': 'My Universe',
#   'original_text': "I was lost in an endless spaceI couldn't find my wayI looked up and I saw your faceAnd heaven came crashing downYou are my universeIt only revolves around youYou're my Venus and MarsThe moon and the starsIn the velvet skyYou are my universeMy light and my darkness tooFor better or worse you are my curseMy universeCounting the stars in the dessert skySparkle's in your eyesMagic moments in the nightShooting comets all aroundYou are my universeIt only revolves around youYou're my Venus and MarsThe moon and the starsIn the velvet skyYou are my universeMy light and my darkness tooFor better or worseYou are my curseMy universeDance a little closer on the milky wayWrapped around eachother we drift awayWe are falling we are flyingDance a little closer on the milky wayWrapped around eachother we drift awayWe are falling we are flyingForeverYou are my universeMy light and my darkness tooFor better or worseYou are my curseMy universe",
#   'tokens': ['lost',
#    'endless',
#    'spacei',
#    'couldnt',
#    'find',
#    'wayi',
#    'looked',
#    'saw',
#    'faceand',
#    'heaven',
#    'came',
#    'crashing',
#    'downyou',
#    'universeit',
#    'revolves',
#    'around',
#    'youyoure',
#    'venus',
#    'marsthe',
#    'moon',
#    'starsin',
#    'velvet',
#    'skyyou',
#    'universemy',
#    'light',
#    'darkness',
#    'toofor',
#    'better',
#    'worse',
#    'cursemy',
#    'universecounting',
#    'stars',
#    'dessert',
#    'skysparkles',
#    'eyesmagic',
#    'moments',
#    'nightshooting',
#    'comets',
#    'aroundyou',
#    'universeit',
#    'revolves',
#    'around',
#    'youyoure',
#    'venus',
#    'marsthe',
#    'moon',
#    'starsin',
#    'velvet',
#    'skyyou',
#    'universemy',
#    'light',
#    'darkness',
#    'toofor',
#    'better',
#    'worseyou',
#    'cursemy',
#    'universedance',
#    'little',
#    'closer',
#    'milky',
#    'waywrapped',
#    'around',
#    'eachother',
#    'drift',
#    'awaywe',
#    'falling',
#    'flyingdance',
#    'little',
#    'closer',
#    'milky',
#    'waywrapped',
#    'around',
#    'eachother',
#    'drift',
#    'awaywe',
#    'falling',
#    'flyingforeveryou',
#    'universemy',
#    'light',
#    'darkness',
#    'toofor',
#    'better',
#    'worseyou',
#    'cursemy',
#    'universe'],
#   'POS': ['VERB',
#    'ADJ',
#    'NOUN',
#    'AUX',
#    'PART',
#    'VERB',
#    'NOUN',
#    'VERB',
#    'VERB',
#    'PROPN',
#    'PROPN',
#    'AUX',
#    'VERB',
#    'NOUN',
#    'NOUN',
#    'VERB',
#    'ADP',
#    'PROPN',
#    'PROPN',
#    'PROPN',
#    'PROPN',
#    'PROPN',
#    'PROPN',
#    'PROPN',
#    'VERB',
#    'ADJ',
#    'NOUN',
#    'ADP',
#    'ADV',
#    'ADJ',
#    'NOUN',
#    'VERB',
#    'NOUN',
#    'NOUN',
#    'NOUN',
#    'ADJ',
#    'NOUN',
#    'VERB',
#    'NOUN',
#    'PROPN',
#    'PROPN',
#    'VERB',
#    'ADP',
#    'PROPN',
#    'PROPN',
#    'PROPN',
#    'PROPN',
#    'PROPN',
#    'PROPN',
#    'PROPN',
#    'VERB',
#    'ADJ',
#    'NOUN',
#    'ADP',
#    'ADJ',
#    'PROPN',
#    'PROPN',
#    'NOUN',
#    'ADV',
#    'ADJ',
#    'ADJ',
#    'VERB',
#    'ADP',
#    'NOUN',
#    'NOUN',
#    'PROPN',
#    'VERB',
#    'NOUN',
#    'ADV',
#    'ADJ',
#    'ADJ',
#    'VERB',
#    'ADP',
#    'NOUN',
#    'NOUN',
#    'PROPN',
#    'VERB',
#    'NOUN',
#    'NOUN',
#    'ADJ',
#    'NOUN',
#    'ADP',
#    'ADJ',
#    'PROPN',
#    'PROPN',
#    'NOUN'],
#   'lemmas': ['lose',
#    'endless',
#    'spacei',
#    'could',
#    'not',
#    'find',
#    'wayi',
#    'look',
#    'see',
#    'faceand',
#    'heaven',
#    'came',
#    'crash',
#    'downyou',
#    'universeit',
#    'revolve',
#    'around',
#    'youyoure',
#    'venus',
#    'marsthe',
#    'moon',
#    'starsin',
#    'velvet',
#    'skyyou',
#    'universemy',
#    'light',
#    'darkness',
#    'toofor',
#    'well',
#    'bad',
#    'cursemy',
#    'universecounte',
#    'star',
#    'dessert',
#    'skysparkle',
#    'eyesmagic',
#    'moment',
#    'nightshoote',
#    'comet',
#    'aroundyou',
#    'universeit',
#    'revolve',
#    'around',
#    'youyoure',
#    'venus',
#    'marsthe',
#    'moon',
#    'starsin',
#    'velvet',
#    'skyyou',
#    'universemy',
#    'light',
#    'darkness',
#    'toofor',
#    'well',
#    'worseyou',
#    'cursemy',
#    'universedance',
#    'little',
#    'close',
#    'milky',
#    'waywrappe',
#    'around',
#    'eachother',
#    'drift',
#    'awaywe',
#    'fall',
#    'flyingdance',
#    'little',
#    'close',
#    'milky',
#    'waywrappe',
#    'around',
#    'eachother',
#    'drift',
#    'awaywe',
#    'fall',
#    'flyingforeveryou',
#    'universemy',
#    'light',
#    'darkness',
#    'toofor',
#    'well',
#    'worseyou',
#    'cursemy',
#    'universe']},
#  {'filename': 'Yellow',
#   'original_text': "Look at the stars,Look how they shine for you,And everything you do,Yeah they were all yellow,I came alongI wrote a song for youAnd all the things you doAnd it was called yellowSo then I took my turnOh what a thing to have doneAnd it was all yellowYour skinOh yeah your skin and bonesTurn into something beautifulYou know you know I love you soYou know I love you soI swam acrossI jumped across for youOh what a thing to doCause you were all yellowI drew a lineI drew a line for youOh what a thing to doAnd it was all yellowYour skinOh yeah your skin and bonesTurn into something beautifulYou know for you I'd bleed myself dryFor you I'd bleed myself dryIt's true look how they shine for youLook how they shine for youLook how they shine for...Look how they shine for youLook how they shine for youLook how they shineLook at the stars look how they shine for youAnd all the things that you do",
#   'tokens': ['look',
#    'starslook',
#    'shine',
#    'youand',
#    'everything',
#    'doyeah',
#    'yellowi',
#    'came',
#    'alongi',
#    'wrote',
#    'song',
#    'youand',
#    'things',
#    'doand',
#    'called',
#    'yellowso',
#    'took',
#    'turnoh',
#    'thing',
#    'doneand',
#    'yellowyour',
#    'skinoh',
#    'yeah',
#    'skin',
#    'bonesturn',
#    'something',
#    'beautifulyou',
#    'know',
#    'know',
#    'love',
#    'soyou',
#    'know',
#    'love',
#    'soi',
#    'swam',
#    'acrossi',
#    'jumped',
#    'across',
#    'youoh',
#    'thing',
#    'docause',
#    'yellowi',
#    'drew',
#    'linei',
#    'drew',
#    'line',
#    'youoh',
#    'thing',
#    'doand',
#    'yellowyour',
#    'skinoh',
#    'yeah',
#    'skin',
#    'bonesturn',
#    'something',
#    'beautifulyou',
#    'know',
#    'id',
#    'bleed',
#    'dryfor',
#    'id',
#    'bleed',
#    'dryits',
#    'true',
#    'look',
#    'shine',
#    'youlook',
#    'shine',
#    'youlook',
#    'shine',
#    'forlook',
#    'shine',
#    'youlook',
#    'shine',
#    'youlook',
#    'shinelook',
#    'stars',
#    'look',
#    'shine',
#    'youand',
#    'things'],
#   'POS': ['VERB',
#    'NOUN',
#    'VERB',
#    'NOUN',
#    'PRON',
#    'NOUN',
#    'NOUN',
#    'VERB',
#    'PROPN',
#    'VERB',
#    'PROPN',
#    'PROPN',
#    'NOUN',
#    'NOUN',
#    'VERB',
#    'PROPN',
#    'VERB',
#    'PROPN',
#    'NOUN',
#    'VERB',
#    'PRON',
#    'PROPN',
#    'INTJ',
#    'NOUN',
#    'NOUN',
#    'PRON',
#    'PRON',
#    'VERB',
#    'VERB',
#    'NOUN',
#    'NOUN',
#    'VERB',
#    'NOUN',
#    'PROPN',
#    'PROPN',
#    'NOUN',
#    'VERB',
#    'ADP',
#    'PROPN',
#    'PROPN',
#    'PROPN',
#    'PROPN',
#    'VERB',
#    'PROPN',
#    'PROPN',
#    'PROPN',
#    'PROPN',
#    'NOUN',
#    'VERB',
#    'INTJ',
#    'PROPN',
#    'INTJ',
#    'NOUN',
#    'NOUN',
#    'PRON',
#    'PRON',
#    'VERB',
#    'PROPN',
#    'PROPN',
#    'PROPN',
#    'PROPN',
#    'PROPN',
#    'PROPN',
#    'NOUN',
#    'NOUN',
#    'ADJ',
#    'NOUN',
#    'NOUN',
#    'NOUN',
#    'NOUN',
#    'NOUN',
#    'VERB',
#    'ADP',
#    'NOUN',
#    'NOUN',
#    'NOUN',
#    'NOUN',
#    'VERB',
#    'NOUN',
#    'AUX',
#    'VERB',
#    'NOUN',
#    'NOUN'],
#   'lemmas': ['look',
#    'starslook',
#    'shine',
#    'youand',
#    'everything',
#    'doyeah',
#    'yellowi',
#    'come',
#    'alongi',
#    'write',
#    'song',
#    'youand',
#    'thing',
#    'doand',
#    'call',
#    'yellowso',
#    'take',
#    'turnoh',
#    'thing',
#    'doneand',
#    'yellowyour',
#    'skinoh',
#    'yeah',
#    'skin',
#    'bonesturn',
#    'something',
#    'beautifulyou',
#    'know',
#    'know',
#    'love',
#    'soyou',
#    'know',
#    'love',
#    'soi',
#    'swam',
#    'acrossi',
#    'jump',
#    'across',
#    'youoh',
#    'thing',
#    'docause',
#    'yellowi',
#    'draw',
#    'linei',
#    'drew',
#    'line',
#    'youoh',
#    'thing',
#    'doand',
#    'yellowyour',
#    'skinoh',
#    'yeah',
#    'skin',
#    'bonesturn',
#    'something',
#    'beautifulyou',
#    'know',
#    'i',
#    'd',
#    'bleed',
#    'dryfor',
#    'i',
#    'd',
#    'bleed',
#    'dryit',
#    'true',
#    'look',
#    'shine',
#    'youlook',
#    'shine',
#    'youlook',
#    'shine',
#    'forlook',
#    'shine',
#    'youlook',
#    'shine',
#    'youlook',
#    'shinelook',
#    'star',
#    'look',
#    'shine',
#    'youand',
#    'thing']},
#  {'filename': 'A Sky Full of Stars',
#   'original_text': "Cause you're a skyCause you're a sky full of starsI'm going to give you my heartCause you're a skyCause you're a sky full of starsAnd cause you light up the pathI don't careGo on and tear me apartI don't care if you doCause in a skyCause in a sky full of starsI think I saw youCause you're a skyCause you're a sky full of starsI want to die in your armsCause you get lighterThe more it gets darkI'm going to give you my heartAnd I don't careGo on and tear me apartI don't care if you doCause in a skyCause in a sky full of starsI think I see youI think I see youBecause you're a skyYou're a sky full of starsSuch a heavenly viewYou're such a heavenly view",
#   'tokens': ['cause',
#    'youre',
#    'skycause',
#    'youre',
#    'sky',
#    'full',
#    'starsim',
#    'going',
#    'give',
#    'heartcause',
#    'youre',
#    'skycause',
#    'youre',
#    'sky',
#    'full',
#    'starsand',
#    'cause',
#    'light',
#    'pathi',
#    'dont',
#    'carego',
#    'tear',
#    'aparti',
#    'dont',
#    'care',
#    'docause',
#    'skycause',
#    'sky',
#    'full',
#    'starsi',
#    'think',
#    'saw',
#    'youcause',
#    'youre',
#    'skycause',
#    'youre',
#    'sky',
#    'full',
#    'starsi',
#    'want',
#    'die',
#    'armscause',
#    'get',
#    'lighterthe',
#    'gets',
#    'darkim',
#    'going',
#    'give',
#    'heartand',
#    'dont',
#    'carego',
#    'tear',
#    'aparti',
#    'dont',
#    'care',
#    'docause',
#    'skycause',
#    'sky',
#    'full',
#    'starsi',
#    'think',
#    'see',
#    'youi',
#    'think',
#    'see',
#    'youbecause',
#    'youre',
#    'skyyoure',
#    'sky',
#    'full',
#    'starssuch',
#    'heavenly',
#    'viewyoure',
#    'heavenly',
#    'view'],
#   'POS': ['SCONJ',
#    'PRON',
#    'VERB',
#    'ADJ',
#    'PRON',
#    'AUX',
#    'NOUN',
#    'ADJ',
#    'NOUN',
#    'VERB',
#    'VERB',
#    'NOUN',
#    'PRON',
#    'VERB',
#    'VERB',
#    'PRON',
#    'VERB',
#    'NOUN',
#    'ADJ',
#    'NOUN',
#    'VERB',
#    'ADJ',
#    'NOUN',
#    'AUX',
#    'PART',
#    'NOUN',
#    'PROPN',
#    'PROPN',
#    'AUX',
#    'PART',
#    'VERB',
#    'NOUN',
#    'PROPN',
#    'NOUN',
#    'ADJ',
#    'ADJ',
#    'NOUN',
#    'VERB',
#    'VERB',
#    'PRON',
#    'VERB',
#    'VERB',
#    'PRON',
#    'AUX',
#    'NOUN',
#    'ADJ',
#    'ADJ',
#    'NOUN',
#    'NOUN',
#    'NOUN',
#    'VERB',
#    'ADJ',
#    'VERB',
#    'PROPN',
#    'VERB',
#    'PROPN',
#    'PROPN',
#    'AUX',
#    'PART',
#    'NOUN',
#    'PROPN',
#    'PROPN',
#    'AUX',
#    'PART',
#    'VERB',
#    'NOUN',
#    'PROPN',
#    'NOUN',
#    'ADJ',
#    'ADJ',
#    'NOUN',
#    'VERB',
#    'PROPN',
#    'VERB',
#    'VERB',
#    'NOUN',
#    'PRON',
#    'VERB',
#    'NOUN',
#    'NOUN',
#    'ADJ',
#    'ADJ',
#    'ADJ',
#    'NOUN',
#    'ADJ',
#    'NOUN'],
#   'lemmas': ['cause',
#    'you',
#    're',
#    'skycause',
#    'you',
#    're',
#    'sky',
#    'full',
#    'starsim',
#    'go',
#    'give',
#    'heartcause',
#    'you',
#    're',
#    'skycause',
#    'you',
#    're',
#    'sky',
#    'full',
#    'starsand',
#    'cause',
#    'light',
#    'pathi',
#    'do',
#    'not',
#    'carego',
#    'tear',
#    'aparti',
#    'do',
#    'not',
#    'care',
#    'docause',
#    'skycause',
#    'sky',
#    'full',
#    'starsi',
#    'think',
#    'see',
#    'youcause',
#    'you',
#    're',
#    'skycause',
#    'you',
#    're',
#    'sky',
#    'full',
#    'starsi',
#    'want',
#    'die',
#    'armscause',
#    'get',
#    'lighterthe',
#    'get',
#    'darkim',
#    'go',
#    'give',
#    'heartand',
#    'do',
#    'not',
#    'carego',
#    'tear',
#    'aparti',
#    'do',
#    'not',
#    'care',
#    'docause',
#    'skycause',
#    'sky',
#    'full',
#    'starsi',
#    'think',
#    'see',
#    'youi',
#    'think',
#    'see',
#    'youbecause',
#    'you',
#    're',
#    'skyyoure',
#    'sky',
#    'full',
#    'starssuch',
#    'heavenly',
#    'viewyoure',
#    'heavenly',
#    'view']},
#  {'filename': 'Trouble',
#   'original_text': "Trouble...Trouble, trouble, trouble, troubleTrouble been doggin' my soul since the day I was bornWorry...Worry, worry, worry, worryWorry just will not seem to leave my mind aloneWe'll I've been...Saved by a womanI've been...Saved by a womanI've been...Saved by a womanShe won't let me goShe won't let me go nowShe won't let me goShe won't let me go nowTrouble...Oh, trouble, trouble, trouble, troubleFeels like every time I get back on my feetShe come around and knock me down againWorry...Oh, worry, worry, worry, worrySometimes I swear it feels like this worry is my only friendWe'll I've been saved...By a womanI've been saved...By a womanI've been saved...By a womanShe won't let me goShe won't let me go nowShe won't let me goShe won't let me go nowOh..., Ahhhh....OhhhhShe good to me nowShe gave me love and affectionShe good tell me nowShe gave me love and affectionI Said I love herYes I love herI said I love herI said I love...She good to me nowShe's good to meShe's good to me",
#   'tokens': ['troubletrouble',
#    'trouble',
#    'trouble',
#    'troubletrouble',
#    'doggin',
#    'soul',
#    'since',
#    'day',
#    'bornworryworry',
#    'worry',
#    'worry',
#    'worryworry',
#    'seem',
#    'leave',
#    'mind',
#    'alonewell',
#    'ive',
#    'beensaved',
#    'womanive',
#    'beensaved',
#    'womanive',
#    'beensaved',
#    'womanshe',
#    'wont',
#    'let',
#    'goshe',
#    'wont',
#    'let',
#    'go',
#    'nowshe',
#    'wont',
#    'let',
#    'goshe',
#    'wont',
#    'let',
#    'go',
#    'nowtroubleoh',
#    'trouble',
#    'trouble',
#    'trouble',
#    'troublefeels',
#    'like',
#    'every',
#    'time',
#    'get',
#    'back',
#    'feetshe',
#    'come',
#    'around',
#    'knock',
#    'againworryoh',
#    'worry',
#    'worry',
#    'worry',
#    'worrysometimes',
#    'swear',
#    'feels',
#    'like',
#    'worry',
#    'friendwell',
#    'ive',
#    'savedby',
#    'womanive',
#    'savedby',
#    'womanive',
#    'savedby',
#    'womanshe',
#    'wont',
#    'let',
#    'goshe',
#    'wont',
#    'let',
#    'go',
#    'nowshe',
#    'wont',
#    'let',
#    'goshe',
#    'wont',
#    'let',
#    'go',
#    'nowoh',
#    'ahhhhohhhhshe',
#    'good',
#    'nowshe',
#    'gave',
#    'love',
#    'affectionshe',
#    'good',
#    'tell',
#    'nowshe',
#    'gave',
#    'love',
#    'affectioni',
#    'said',
#    'love',
#    'heryes',
#    'love',
#    'heri',
#    'said',
#    'love',
#    'heri',
#    'said',
#    'loveshe',
#    'good',
#    'nowshes',
#    'good',
#    'meshes',
#    'good'],
#   'POS': ['ADJ',
#    'NOUN',
#    'NOUN',
#    'ADJ',
#    'ADJ',
#    'NOUN',
#    'SCONJ',
#    'NOUN',
#    'NOUN',
#    'NOUN',
#    'NOUN',
#    'NOUN',
#    'VERB',
#    'VERB',
#    'NOUN',
#    'PROPN',
#    'PRON',
#    'AUX',
#    'VERB',
#    'PROPN',
#    'PROPN',
#    'PROPN',
#    'PROPN',
#    'PROPN',
#    'AUX',
#    'PART',
#    'VERB',
#    'PRON',
#    'AUX',
#    'PART',
#    'VERB',
#    'VERB',
#    'PROPN',
#    'AUX',
#    'PART',
#    'VERB',
#    'PRON',
#    'AUX',
#    'PART',
#    'VERB',
#    'VERB',
#    'VERB',
#    'NOUN',
#    'NOUN',
#    'NOUN',
#    'NOUN',
#    'SCONJ',
#    'DET',
#    'NOUN',
#    'VERB',
#    'ADV',
#    'NOUN',
#    'VERB',
#    'ADV',
#    'NOUN',
#    'PROPN',
#    'PROPN',
#    'NOUN',
#    'PROPN',
#    'NOUN',
#    'NOUN',
#    'VERB',
#    'ADP',
#    'NOUN',
#    'ADJ',
#    'PRON',
#    'AUX',
#    'ADJ',
#    'ADJ',
#    'PROPN',
#    'PROPN',
#    'PROPN',
#    'PROPN',
#    'AUX',
#    'PART',
#    'VERB',
#    'PRON',
#    'AUX',
#    'PART',
#    'VERB',
#    'VERB',
#    'PROPN',
#    'AUX',
#    'PART',
#    'VERB',
#    'PRON',
#    'AUX',
#    'PART',
#    'VERB',
#    'VERB',
#    'ADJ',
#    'NOUN',
#    'ADJ',
#    'NOUN',
#    'VERB',
#    'NOUN',
#    'NOUN',
#    'PROPN',
#    'PROPN',
#    'PROPN',
#    'VERB',
#    'PROPN',
#    'PROPN',
#    'VERB',
#    'PROPN',
#    'PROPN',
#    'PROPN',
#    'PROPN',
#    'VERB',
#    'PROPN',
#    'PROPN',
#    'VERB',
#    'PROPN',
#    'PROPN',
#    'VERB',
#    'ADJ',
#    'NOUN',
#    'ADJ'],
#   'lemmas': ['troubletrouble',
#    'trouble',
#    'trouble',
#    'troubletrouble',
#    'doggin',
#    'soul',
#    'since',
#    'day',
#    'bornworryworry',
#    'worry',
#    'worry',
#    'worryworry',
#    'seem',
#    'leave',
#    'mind',
#    'alonewell',
#    'I',
#    've',
#    'beensave',
#    'womanive',
#    'beensaved',
#    'womanive',
#    'beensaved',
#    'womanshe',
#    'will',
#    'not',
#    'let',
#    'goshe',
#    'will',
#    'not',
#    'let',
#    'go',
#    'nowshe',
#    'will',
#    'not',
#    'let',
#    'goshe',
#    'will',
#    'not',
#    'let',
#    'go',
#    'nowtroubleoh',
#    'trouble',
#    'trouble',
#    'trouble',
#    'troublefeel',
#    'like',
#    'every',
#    'time',
#    'get',
#    'back',
#    'feetshe',
#    'come',
#    'around',
#    'knock',
#    'againworryoh',
#    'worry',
#    'worry',
#    'worry',
#    'worrysometime',
#    'swear',
#    'feel',
#    'like',
#    'worry',
#    'friendwell',
#    'I',
#    've',
#    'savedby',
#    'womanive',
#    'savedby',
#    'womanive',
#    'savedby',
#    'womanshe',
#    'will',
#    'not',
#    'let',
#    'goshe',
#    'will',
#    'not',
#    'let',
#    'go',
#    'nowshe',
#    'will',
#    'not',
#    'let',
#    'goshe',
#    'will',
#    'not',
#    'let',
#    'go',
#    'nowoh',
#    'ahhhhohhhhshe',
#    'good',
#    'nowshe',
#    'give',
#    'love',
#    'affectionshe',
#    'good',
#    'tell',
#    'nowshe',
#    'give',
#    'love',
#    'affectioni',
#    'say',
#    'love',
#    'heryes',
#    'love',
#    'heri',
#    'say',
#    'love',
#    'heri',
#    'say',
#    'loveshe',
#    'good',
#    'nowshe',
#    'good',
#    'mesh',
#    'good']},
#  {'filename': 'Princess of China',
#   'original_text': "[Verse 1]Once upon a time somebody ran,Somebody ran away saying fast as I can.I got to go, I got to go!Once upon a time we fell apart,You holding in your hands the two halves of my heart.Oh oh. Oh oh!Once upon a time we're burning bright,Now all we ever seem to do is fight.On and on, and on, and on, and on.Once upon a time on the same side,Once upon a time on the same side in the same game.And why'd you have to go,Have to go and throw it all in my face?[Pre-Chorus]I could've been a princess, you'd be a king,Could've had a castle and worn a ring,But no, you let me go.I could've been a princess, you'd be a king,Could've had a castle and wore a ring,But no, you let me go.[Hook]You stole my star, lalala la lala, lalala la lala, lala la lala.You stole my star, lalala la lala.[Outro]Cause you really hurt me,Oh, you really hurt me.Cause you really hurt me,Oh, you really hurt me.Cause you really hurt me,Oh, you really hurt me, oh.You really hurt me,Oh, you really hurt me.Cause you really hurt me,Oh, you really hurt me.",
#   'tokens': ['verse',
#    '1once',
#    'upon',
#    'time',
#    'somebody',
#    'ransomebody',
#    'ran',
#    'away',
#    'saying',
#    'fast',
#    'cani',
#    'got',
#    'go',
#    'got',
#    'goonce',
#    'upon',
#    'time',
#    'fell',
#    'apartyou',
#    'holding',
#    'hands',
#    'two',
#    'halves',
#    'heartoh',
#    'oh',
#    'oh',
#    'ohonce',
#    'upon',
#    'time',
#    'burning',
#    'brightnow',
#    'ever',
#    'seem',
#    'fighton',
#    'ononce',
#    'upon',
#    'time',
#    'sideonce',
#    'upon',
#    'time',
#    'side',
#    'gameand',
#    'whyd',
#    'gohave',
#    'go',
#    'throw',
#    'faceprechorusi',
#    'couldve',
#    'princess',
#    'youd',
#    'kingcouldve',
#    'castle',
#    'worn',
#    'ringbut',
#    'let',
#    'goi',
#    'couldve',
#    'princess',
#    'youd',
#    'kingcouldve',
#    'castle',
#    'wore',
#    'ringbut',
#    'let',
#    'gohookyou',
#    'stole',
#    'star',
#    'lalala',
#    'la',
#    'lala',
#    'lalala',
#    'la',
#    'lala',
#    'lala',
#    'la',
#    'lalayou',
#    'stole',
#    'star',
#    'lalala',
#    'la',
#    'lalaoutrocause',
#    'really',
#    'hurt',
#    'meoh',
#    'really',
#    'hurt',
#    'mecause',
#    'really',
#    'hurt',
#    'meoh',
#    'really',
#    'hurt',
#    'mecause',
#    'really',
#    'hurt',
#    'meoh',
#    'really',
#    'hurt',
#    'ohyou',
#    'really',
#    'hurt',
#    'meoh',
#    'really',
#    'hurt',
#    'mecause',
#    'really',
#    'hurt',
#    'meoh',
#    'really',
#    'hurt'],
#   'POS': ['NOUN',
#    'PROPN',
#    'SCONJ',
#    'NOUN',
#    'PRON',
#    'NOUN',
#    'VERB',
#    'ADV',
#    'VERB',
#    'ADJ',
#    'NOUN',
#    'AUX',
#    'VERB',
#    'VERB',
#    'NOUN',
#    'SCONJ',
#    'NOUN',
#    'VERB',
#    'ADV',
#    'VERB',
#    'NOUN',
#    'NUM',
#    'NOUN',
#    'NOUN',
#    'INTJ',
#    'INTJ',
#    'NOUN',
#    'SCONJ',
#    'NOUN',
#    'VERB',
#    'PROPN',
#    'ADV',
#    'VERB',
#    'PROPN',
#    'NOUN',
#    'SCONJ',
#    'NOUN',
#    'NOUN',
#    'SCONJ',
#    'NOUN',
#    'NOUN',
#    'NOUN',
#    'SCONJ',
#    'PROPN',
#    'NOUN',
#    'VERB',
#    'VERB',
#    'NOUN',
#    'AUX',
#    'AUX',
#    'VERB',
#    'PRON',
#    'PROPN',
#    'NOUN',
#    'PROPN',
#    'VERB',
#    'INTJ',
#    'VERB',
#    'PROPN',
#    'AUX',
#    'AUX',
#    'VERB',
#    'PRON',
#    'PROPN',
#    'NOUN',
#    'PROPN',
#    'VERB',
#    'INTJ',
#    'VERB',
#    'PROPN',
#    'VERB',
#    'PROPN',
#    'PROPN',
#    'PROPN',
#    'PROPN',
#    'PROPN',
#    'PROPN',
#    'PROPN',
#    'PROPN',
#    'PROPN',
#    'PROPN',
#    'VERB',
#    'PROPN',
#    'PROPN',
#    'PRON',
#    'NOUN',
#    'ADV',
#    'VERB',
#    'NOUN',
#    'ADV',
#    'VERB',
#    'PROPN',
#    'ADV',
#    'VERB',
#    'NOUN',
#    'ADV',
#    'VERB',
#    'PROPN',
#    'ADV',
#    'VERB',
#    'NOUN',
#    'ADV',
#    'VERB',
#    'PROPN',
#    'ADV',
#    'VERB',
#    'NOUN',
#    'ADV',
#    'VERB',
#    'PROPN',
#    'ADV',
#    'VERB',
#    'NOUN',
#    'ADV',
#    'VERB'],
#   'lemmas': ['verse',
#    '1once',
#    'upon',
#    'time',
#    'somebody',
#    'ransomebody',
#    'run',
#    'away',
#    'say',
#    'fast',
#    'cani',
#    'get',
#    'go',
#    'get',
#    'goonce',
#    'upon',
#    'time',
#    'fall',
#    'apartyou',
#    'hold',
#    'hand',
#    'two',
#    'half',
#    'heartoh',
#    'oh',
#    'oh',
#    'ohonce',
#    'upon',
#    'time',
#    'burn',
#    'brightnow',
#    'ever',
#    'seem',
#    'fighton',
#    'ononce',
#    'upon',
#    'time',
#    'sideonce',
#    'upon',
#    'time',
#    'side',
#    'gameand',
#    'why',
#    'd',
#    'gohave',
#    'go',
#    'throw',
#    'faceprechorusi',
#    'could',
#    've',
#    'princess',
#    'you',
#    'd',
#    'kingcouldve',
#    'castle',
#    'wear',
#    'ringbut',
#    'let',
#    'goi',
#    'could',
#    've',
#    'princess',
#    'you',
#    'd',
#    'kingcouldve',
#    'castle',
#    'wear',
#    'ringbut',
#    'let',
#    'gohookyou',
#    'stole',
#    'star',
#    'lalala',
#    'la',
#    'lala',
#    'lalala',
#    'la',
#    'lala',
#    'lala',
#    'la',
#    'lalayou',
#    'steal',
#    'star',
#    'lalala',
#    'la',
#    'lalaoutrocause',
#    'really',
#    'hurt',
#    'meoh',
#    'really',
#    'hurt',
#    'mecause',
#    'really',
#    'hurt',
#    'meoh',
#    'really',
#    'hurt',
#    'mecause',
#    'really',
#    'hurt',
#    'meoh',
#    'really',
#    'hurt',
#    'ohyou',
#    'really',
#    'hurt',
#    'meoh',
#    'really',
#    'hurt',
#    'mecause',
#    'really',
#    'hurt',
#    'meoh',
#    'really',
#    'hurt']},
#  {'filename': 'Clocks',
#   'original_text': "Lights go out and I can't be savedTides that I tried to swim againstYou've put me down upon my kneesOh I beg, I beg and plead (singing)Come out of things unsaid, shoot an apple off my head (and a)Trouble that can't be named, a tiger's waiting to be tamed (singing)You are, you areConfusion never stops, closing walls and ticking clocks (gonna)Come back and take you home, I could not stop that you now know (singing)Come out upon my seas, curse missed opportunities (am I)A part of the cure, or am I part of the disease (singing)You are [4x] (singing)You are [2x]And nothing else comparesOh no nothing else comparesOh and nothing else comparesYou are [continues in background]Home, home, where I wanted to go [2x](I went)Home, home, where I wanted to go (I went)Home, home, where I wanted to go",
#   'tokens': ['lights',
#    'go',
#    'cant',
#    'savedtides',
#    'tried',
#    'swim',
#    'againstyouve',
#    'put',
#    'upon',
#    'kneesoh',
#    'beg',
#    'beg',
#    'plead',
#    'singingcome',
#    'things',
#    'unsaid',
#    'shoot',
#    'apple',
#    'head',
#    'atrouble',
#    'cant',
#    'named',
#    'tigers',
#    'waiting',
#    'tamed',
#    'singingyou',
#    'areconfusion',
#    'never',
#    'stops',
#    'closing',
#    'walls',
#    'ticking',
#    'clocks',
#    'gonnacome',
#    'back',
#    'take',
#    'home',
#    'could',
#    'stop',
#    'know',
#    'singingcome',
#    'upon',
#    'seas',
#    'curse',
#    'missed',
#    'opportunities',
#    'ia',
#    'part',
#    'cure',
#    'part',
#    'disease',
#    'singingyou',
#    '4x',
#    'singingyou',
#    '2xand',
#    'nothing',
#    'else',
#    'comparesoh',
#    'nothing',
#    'else',
#    'comparesoh',
#    'nothing',
#    'else',
#    'comparesyou',
#    'continues',
#    'backgroundhome',
#    'home',
#    'wanted',
#    'go',
#    '2xi',
#    'wenthome',
#    'home',
#    'wanted',
#    'go',
#    'wenthome',
#    'home',
#    'wanted',
#    'go'],
#   'POS': ['NOUN',
#    'VERB',
#    'AUX',
#    'PART',
#    'NOUN',
#    'VERB',
#    'NOUN',
#    'NOUN',
#    'VERB',
#    'SCONJ',
#    'PROPN',
#    'PROPN',
#    'NOUN',
#    'VERB',
#    'ADJ',
#    'NOUN',
#    'ADJ',
#    'VERB',
#    'PROPN',
#    'NOUN',
#    'ADJ',
#    'AUX',
#    'PART',
#    'VERB',
#    'NOUN',
#    'VERB',
#    'VERB',
#    'NOUN',
#    'NOUN',
#    'ADV',
#    'VERB',
#    'NOUN',
#    'NOUN',
#    'VERB',
#    'NOUN',
#    'VERB',
#    'ADP',
#    'NOUN',
#    'NOUN',
#    'AUX',
#    'VERB',
#    'VERB',
#    'ADV',
#    'SCONJ',
#    'NOUN',
#    'VERB',
#    'VERB',
#    'NOUN',
#    'VERB',
#    'NOUN',
#    'ADJ',
#    'NOUN',
#    'NOUN',
#    'NOUN',
#    'NUM',
#    'NOUN',
#    'NUM',
#    'PRON',
#    'ADV',
#    'VERB',
#    'PRON',
#    'ADV',
#    'VERB',
#    'PRON',
#    'ADV',
#    'NOUN',
#    'VERB',
#    'ADJ',
#    'NOUN',
#    'VERB',
#    'VERB',
#    'ADJ',
#    'PROPN',
#    'PROPN',
#    'VERB',
#    'VERB',
#    'ADJ',
#    'NOUN',
#    'VERB',
#    'VERB'],
#   'lemmas': ['light',
#    'go',
#    'can',
#    'not',
#    'savedtide',
#    'try',
#    'swim',
#    'againstyouve',
#    'put',
#    'upon',
#    'kneesoh',
#    'beg',
#    'beg',
#    'plead',
#    'singingcome',
#    'thing',
#    'unsaid',
#    'shoot',
#    'apple',
#    'head',
#    'atrouble',
#    'can',
#    'not',
#    'name',
#    'tiger',
#    'wait',
#    'tame',
#    'singingyou',
#    'areconfusion',
#    'never',
#    'stop',
#    'closing',
#    'wall',
#    'tick',
#    'clock',
#    'gonnacome',
#    'back',
#    'take',
#    'home',
#    'could',
#    'stop',
#    'know',
#    'singingcome',
#    'upon',
#    'sea',
#    'curse',
#    'miss',
#    'opportunity',
#    'ia',
#    'part',
#    'cure',
#    'part',
#    'disease',
#    'singingyou',
#    '4x',
#    'singingyou',
#    '2xand',
#    'nothing',
#    'else',
#    'comparesoh',
#    'nothing',
#    'else',
#    'comparesoh',
#    'nothing',
#    'else',
#    'comparesyou',
#    'continue',
#    'backgroundhome',
#    'home',
#    'want',
#    'go',
#    '2xi',
#    'wenthome',
#    'home',
#    'want',
#    'go',
#    'wenthome',
#    'home',
#    'want',
#    'go']},
#  {'filename': 'Sparks',
#   'original_text': '[Verse 1]Did I drive you away?I know what you\'ll sayYou say, "Oh, sing one you know"But I promise you thisI\'ll always look out for youYeah, that\'s what I\'ll do[Chorus]I say, ohI say, oh[Verse 2]My heart is yoursIt\'s you that I hold on toYeah, that\'s what I doAnd I know I was wrongBut I won\'t let you downOh yeah, oh yeah, oh yeah, I will, yes I will[Chorus]I said, ohI cry, oh[Bridge]Yeah, I saw sparksYeah, I saw sparksAnd I saw sparksYeah, I saw sparksSing it out[Outro]La, la, la, la, oh…La, la, la, la, oh…La, la, la, la, oh…La, la, la, la, oh…',
#   'tokens': ['verse',
#    '1did',
#    'drive',
#    'awayi',
#    'know',
#    'youll',
#    'sayyou',
#    'say',
#    'oh',
#    'sing',
#    'one',
#    'knowbut',
#    'promise',
#    'thisill',
#    'always',
#    'look',
#    'youyeah',
#    'thats',
#    'ill',
#    'dochorusi',
#    'say',
#    'ohi',
#    'say',
#    'ohverse',
#    '2my',
#    'heart',
#    'yoursits',
#    'hold',
#    'toyeah',
#    'thats',
#    'doand',
#    'know',
#    'wrongbut',
#    'wont',
#    'let',
#    'downoh',
#    'yeah',
#    'oh',
#    'yeah',
#    'oh',
#    'yeah',
#    'yes',
#    'willchorusi',
#    'said',
#    'ohi',
#    'cry',
#    'ohbridgeyeah',
#    'saw',
#    'sparksyeah',
#    'saw',
#    'sparksand',
#    'saw',
#    'sparksyeah',
#    'saw',
#    'sparkssing',
#    'outoutrola',
#    'la',
#    'la',
#    'la',
#    'oh…la',
#    'la',
#    'la',
#    'la',
#    'oh…la',
#    'la',
#    'la',
#    'la',
#    'oh…la',
#    'la',
#    'la',
#    'la',
#    'oh…'],
#   'POS': ['NOUN',
#    'X',
#    'NOUN',
#    'NOUN',
#    'VERB',
#    'PRON',
#    'AUX',
#    'PRON',
#    'VERB',
#    'INTJ',
#    'VERB',
#    'NUM',
#    'PROPN',
#    'NOUN',
#    'AUX',
#    'ADV',
#    'VERB',
#    'NOUN',
#    'PRON',
#    'VERB',
#    'ADJ',
#    'NOUN',
#    'VERB',
#    'PROPN',
#    'VERB',
#    'ADJ',
#    'ADJ',
#    'NOUN',
#    'NOUN',
#    'VERB',
#    'NOUN',
#    'PRON',
#    'VERB',
#    'NOUN',
#    'VERB',
#    'PROPN',
#    'AUX',
#    'PART',
#    'VERB',
#    'NOUN',
#    'INTJ',
#    'INTJ',
#    'INTJ',
#    'INTJ',
#    'INTJ',
#    'INTJ',
#    'PROPN',
#    'VERB',
#    'PROPN',
#    'PROPN',
#    'PROPN',
#    'VERB',
#    'PROPN',
#    'VERB',
#    'NOUN',
#    'VERB',
#    'PROPN',
#    'VERB',
#    'VERB',
#    'PROPN',
#    'X',
#    'X',
#    'PROPN',
#    'INTJ',
#    'VERB',
#    'PROPN',
#    'X',
#    'PROPN',
#    'PROPN',
#    'INTJ',
#    'VERB',
#    'PROPN',
#    'X',
#    'PROPN',
#    'PROPN',
#    'INTJ',
#    'VERB',
#    'PROPN',
#    'X',
#    'PROPN',
#    'PROPN',
#    'INTJ',
#    'PUNCT'],
#   'lemmas': ['verse',
#    '1did',
#    'drive',
#    'awayi',
#    'know',
#    'you',
#    'll',
#    'sayyou',
#    'say',
#    'oh',
#    'sing',
#    'one',
#    'knowbut',
#    'promise',
#    'thisill',
#    'always',
#    'look',
#    'youyeah',
#    'that',
#    's',
#    'ill',
#    'dochorusi',
#    'say',
#    'ohi',
#    'say',
#    'ohverse',
#    '2my',
#    'heart',
#    'yoursit',
#    'hold',
#    'toyeah',
#    'that',
#    's',
#    'doand',
#    'know',
#    'wrongbut',
#    'will',
#    'not',
#    'let',
#    'downoh',
#    'yeah',
#    'oh',
#    'yeah',
#    'oh',
#    'yeah',
#    'yes',
#    'willchorusi',
#    'say',
#    'ohi',
#    'cry',
#    'ohbridgeyeah',
#    'see',
#    'sparksyeah',
#    'see',
#    'sparksand',
#    'see',
#    'sparksyeah',
#    'see',
#    'sparksse',
#    'outoutrola',
#    'la',
#    'la',
#    'la',
#    'oh',
#    '…',
#    'la',
#    'la',
#    'la',
#    'la',
#    'oh',
#    '…',
#    'la',
#    'la',
#    'la',
#    'la',
#    'oh',
#    '…',
#    'la',
#    'la',
#    'la',
#    'la',
#    'oh',
#    '…']},
#  {'filename': 'In My Place',
#   'original_text': "In my place, in my placeWere lines that I couldn't changeI was lost, oh yeahI was lost, I was lostCrossed lines I shouldn't have crossedI was lost, oh yeahYeah, how long must you wait for it?Yeah, how long must you pay for it?Yeah, how long must you wait for it?For it...I was scared, I was scaredTired and underpreparedBut I'll wait for itIf you go, if you goAnd leave me down here on my ownThen I'll wait for youYeah, how long must you wait for it?Yeah, how long must you pay for it?Yeah, how long must you wait for it?Singing please, please, pleaseCome back and sing to meTo me, meCome on and sing it out, now, nowCome on and sing it out...  To me, meCome back and sing itIn my place, in my placeWere lines that I couldn't changeAnd I was lost, oh yeahOh yeah",
#   'tokens': ['place',
#    'placewere',
#    'lines',
#    'couldnt',
#    'changei',
#    'lost',
#    'oh',
#    'yeahi',
#    'lost',
#    'lostcrossed',
#    'lines',
#    'shouldnt',
#    'crossedi',
#    'lost',
#    'oh',
#    'yeahyeah',
#    'long',
#    'must',
#    'wait',
#    'ityeah',
#    'long',
#    'must',
#    'pay',
#    'ityeah',
#    'long',
#    'must',
#    'wait',
#    'itfor',
#    'iti',
#    'scared',
#    'scaredtired',
#    'underpreparedbut',
#    'ill',
#    'wait',
#    'itif',
#    'go',
#    'goand',
#    'leave',
#    'ownthen',
#    'ill',
#    'wait',
#    'youyeah',
#    'long',
#    'must',
#    'wait',
#    'ityeah',
#    'long',
#    'must',
#    'pay',
#    'ityeah',
#    'long',
#    'must',
#    'wait',
#    'itsinging',
#    'please',
#    'please',
#    'pleasecome',
#    'back',
#    'sing',
#    'meto',
#    'mecome',
#    'sing',
#    'nowcome',
#    'sing',
#    'mecome',
#    'back',
#    'sing',
#    'itin',
#    'place',
#    'placewere',
#    'lines',
#    'couldnt',
#    'changeand',
#    'lost',
#    'oh',
#    'yeahoh',
#    'yeah'],
#   'POS': ['PROPN',
#    'NOUN',
#    'NOUN',
#    'AUX',
#    'PART',
#    'ADV',
#    'VERB',
#    'INTJ',
#    'NOUN',
#    'VERB',
#    'VERB',
#    'NOUN',
#    'AUX',
#    'PART',
#    'VERB',
#    'VERB',
#    'INTJ',
#    'INTJ',
#    'ADV',
#    'AUX',
#    'VERB',
#    'PROPN',
#    'ADV',
#    'AUX',
#    'VERB',
#    'VERB',
#    'ADV',
#    'AUX',
#    'VERB',
#    'ADP',
#    'PROPN',
#    'PROPN',
#    'VERB',
#    'PROPN',
#    'PROPN',
#    'NOUN',
#    'NOUN',
#    'VERB',
#    'PROPN',
#    'PROPN',
#    'PROPN',
#    'PROPN',
#    'NOUN',
#    'PROPN',
#    'ADV',
#    'AUX',
#    'VERB',
#    'PROPN',
#    'ADV',
#    'AUX',
#    'VERB',
#    'VERB',
#    'ADV',
#    'AUX',
#    'VERB',
#    'VERB',
#    'INTJ',
#    'INTJ',
#    'VERB',
#    'ADV',
#    'NOUN',
#    'ADJ',
#    'NOUN',
#    'VERB',
#    'NOUN',
#    'NOUN',
#    'VERB',
#    'ADV',
#    'VERB',
#    'NOUN',
#    'NOUN',
#    'NOUN',
#    'NOUN',
#    'AUX',
#    'PART',
#    'VERB',
#    'VERB',
#    'INTJ',
#    'INTJ',
#    'INTJ'],
#   'lemmas': ['place',
#    'placewere',
#    'line',
#    'could',
#    'not',
#    'changei',
#    'lose',
#    'oh',
#    'yeahi',
#    'lose',
#    'lostcrosse',
#    'line',
#    'should',
#    'not',
#    'crossedi',
#    'lose',
#    'oh',
#    'yeahyeah',
#    'long',
#    'must',
#    'wait',
#    'ityeah',
#    'long',
#    'must',
#    'pay',
#    'ityeah',
#    'long',
#    'must',
#    'wait',
#    'itfor',
#    'iti',
#    'scared',
#    'scaredtire',
#    'underpreparedbut',
#    'ill',
#    'wait',
#    'itif',
#    'go',
#    'goand',
#    'leave',
#    'ownthen',
#    'ill',
#    'wait',
#    'youyeah',
#    'long',
#    'must',
#    'wait',
#    'ityeah',
#    'long',
#    'must',
#    'pay',
#    'ityeah',
#    'long',
#    'must',
#    'wait',
#    'itsinge',
#    'please',
#    'please',
#    'pleasecome',
#    'back',
#    'sing',
#    'meto',
#    'mecome',
#    'sing',
#    'nowcome',
#    'sing',
#    'mecome',
#    'back',
#    'sing',
#    'itin',
#    'place',
#    'placewere',
#    'line',
#    'could',
#    'not',
#    'changeand',
#    'lose',
#    'oh',
#    'yeahoh',
#    'yeah']},
#  {'filename': 'Viva La Vida',
#   'original_text': 'I used to rule the worldSeas would rise when I gave the wordNow in the morning I sleep aloneSweep the streets I used to ownI used to roll the diceFeel the fear in my enemy\'s eyesListen as the crowd would sing"Now the old king is dead! Long live the king!"One minute I held the keyNext the walls were closed on meAnd I discovered that my castles standUpon pillars of salt and pillars of sandI hear Jerusalem bells are ringingRoman Cavalry choirs are singingBe my mirror, my sword and shieldMy missionaries in a foreign fieldFor some reason I can\'t explainOnce you go there was neverNever an honest wordAnd that was when I ruled the worldIt was the wicked and wild windBlew down the doors to let me inShattered windows and the sound of drumsPeople couldn\'t believe what I\'d becomeRevolutionaries waitFor my head on a silver plateJust a puppet on a lonely stringOh who would ever want to be king?I hear Jerusalem bells are ringingRoman Cavalry choirs are singingBe my mirror, my sword and shieldMy missionaries in a foreign fieldFor some reason I can\'t explainI know Saint Peter won\'t call my nameNever an honest wordBut that was when I ruled the worldI hear Jerusalem bells are ringingRoman Cavalry choirs are singingBe my mirror, my sword and shieldMy missionaries in a foreign fieldFor some reason I can\'t explainI know Saint Peter won\'t call my nameNever an honest wordBut that was when I ruled the world',
#   'tokens': ['used',
#    'rule',
#    'worldseas',
#    'would',
#    'rise',
#    'gave',
#    'wordnow',
#    'morning',
#    'sleep',
#    'alonesweep',
#    'streets',
#    'used',
#    'owni',
#    'used',
#    'roll',
#    'dicefeel',
#    'fear',
#    'enemys',
#    'eyeslisten',
#    'crowd',
#    'would',
#    'singnow',
#    'old',
#    'king',
#    'dead',
#    'long',
#    'live',
#    'kingone',
#    'minute',
#    'held',
#    'keynext',
#    'walls',
#    'closed',
#    'meand',
#    'discovered',
#    'castles',
#    'standupon',
#    'pillars',
#    'salt',
#    'pillars',
#    'sandi',
#    'hear',
#    'jerusalem',
#    'bells',
#    'ringingroman',
#    'cavalry',
#    'choirs',
#    'singingbe',
#    'mirror',
#    'sword',
#    'shieldmy',
#    'missionaries',
#    'foreign',
#    'fieldfor',
#    'reason',
#    'cant',
#    'explainonce',
#    'go',
#    'nevernever',
#    'honest',
#    'wordand',
#    'ruled',
#    'worldit',
#    'wicked',
#    'wild',
#    'windblew',
#    'doors',
#    'let',
#    'inshattered',
#    'windows',
#    'sound',
#    'drumspeople',
#    'couldnt',
#    'believe',
#    'id',
#    'becomerevolutionaries',
#    'waitfor',
#    'head',
#    'silver',
#    'platejust',
#    'puppet',
#    'lonely',
#    'stringoh',
#    'would',
#    'ever',
#    'want',
#    'kingi',
#    'hear',
#    'jerusalem',
#    'bells',
#    'ringingroman',
#    'cavalry',
#    'choirs',
#    'singingbe',
#    'mirror',
#    'sword',
#    'shieldmy',
#    'missionaries',
#    'foreign',
#    'fieldfor',
#    'reason',
#    'cant',
#    'explaini',
#    'know',
#    'saint',
#    'peter',
#    'wont',
#    'call',
#    'namenever',
#    'honest',
#    'wordbut',
#    'ruled',
#    'worldi',
#    'hear',
#    'jerusalem',
#    'bells',
#    'ringingroman',
#    'cavalry',
#    'choirs',
#    'singingbe',
#    'mirror',
#    'sword',
#    'shieldmy',
#    'missionaries',
#    'foreign',
#    'fieldfor',
#    'reason',
#    'cant',
#    'explaini',
#    'know',
#    'saint',
#    'peter',
#    'wont',
#    'call',
#    'namenever',
#    'honest',
#    'wordbut',
#    'ruled',
#    'world'],
#   'POS': ['VERB',
#    'NOUN',
#    'NOUN',
#    'AUX',
#    'VERB',
#    'VERB',
#    'PROPN',
#    'NOUN',
#    'NOUN',
#    'NOUN',
#    'NOUN',
#    'VERB',
#    'NOUN',
#    'VERB',
#    'NOUN',
#    'NOUN',
#    'NOUN',
#    'PROPN',
#    'VERB',
#    'NOUN',
#    'AUX',
#    'VERB',
#    'ADJ',
#    'NOUN',
#    'ADJ',
#    'ADV',
#    'ADJ',
#    'PROPN',
#    'NOUN',
#    'VERB',
#    'NOUN',
#    'NOUN',
#    'VERB',
#    'PROPN',
#    'VERB',
#    'NOUN',
#    'NOUN',
#    'VERB',
#    'NOUN',
#    'NOUN',
#    'PROPN',
#    'VERB',
#    'PROPN',
#    'VERB',
#    'NOUN',
#    'NOUN',
#    'NOUN',
#    'NOUN',
#    'PROPN',
#    'NOUN',
#    'PROPN',
#    'NOUN',
#    'ADJ',
#    'PROPN',
#    'NOUN',
#    'AUX',
#    'PART',
#    'VERB',
#    'VERB',
#    'NOUN',
#    'ADJ',
#    'ADV',
#    'VERB',
#    'NOUN',
#    'ADJ',
#    'ADJ',
#    'NOUN',
#    'NOUN',
#    'VERB',
#    'VERB',
#    'NOUN',
#    'ADJ',
#    'NOUN',
#    'AUX',
#    'PART',
#    'VERB',
#    'PROPN',
#    'PROPN',
#    'NOUN',
#    'PROPN',
#    'PROPN',
#    'PROPN',
#    'PROPN',
#    'NOUN',
#    'ADJ',
#    'NOUN',
#    'AUX',
#    'ADV',
#    'VERB',
#    'PROPN',
#    'VERB',
#    'PROPN',
#    'VERB',
#    'NOUN',
#    'NOUN',
#    'NOUN',
#    'NOUN',
#    'PROPN',
#    'NOUN',
#    'PROPN',
#    'NOUN',
#    'ADJ',
#    'PROPN',
#    'NOUN',
#    'AUX',
#    'PART',
#    'NOUN',
#    'PROPN',
#    'PROPN',
#    'PROPN',
#    'AUX',
#    'PART',
#    'VERB',
#    'ADV',
#    'ADJ',
#    'PROPN',
#    'VERB',
#    'PROPN',
#    'VERB',
#    'PROPN',
#    'VERB',
#    'NOUN',
#    'NOUN',
#    'NOUN',
#    'NOUN',
#    'PROPN',
#    'NOUN',
#    'PROPN',
#    'NOUN',
#    'ADJ',
#    'PROPN',
#    'NOUN',
#    'AUX',
#    'PART',
#    'NOUN',
#    'PROPN',
#    'PROPN',
#    'PROPN',
#    'AUX',
#    'PART',
#    'VERB',
#    'ADV',
#    'ADJ',
#    'ADV',
#    'VERB',
#    'NOUN'],
#   'lemmas': ['use',
#    'rule',
#    'worldsea',
#    'would',
#    'rise',
#    'give',
#    'wordnow',
#    'morning',
#    'sleep',
#    'alonesweep',
#    'street',
#    'use',
#    'owni',
#    'use',
#    'roll',
#    'dicefeel',
#    'fear',
#    'enemys',
#    'eyeslisten',
#    'crowd',
#    'would',
#    'singnow',
#    'old',
#    'king',
#    'dead',
#    'long',
#    'live',
#    'kingone',
#    'minute',
#    'hold',
#    'keynext',
#    'wall',
#    'close',
#    'meand',
#    'discover',
#    'castle',
#    'standupon',
#    'pillar',
#    'salt',
#    'pillar',
#    'sandi',
#    'hear',
#    'jerusalem',
#    'bell',
#    'ringingroman',
#    'cavalry',
#    'choir',
#    'singingbe',
#    'mirror',
#    'sword',
#    'shieldmy',
#    'missionary',
#    'foreign',
#    'fieldfor',
#    'reason',
#    'can',
#    'not',
#    'explainonce',
#    'go',
#    'nevernever',
#    'honest',
#    'wordand',
#    'rule',
#    'worldit',
#    'wicked',
#    'wild',
#    'windblew',
#    'door',
#    'let',
#    'inshattere',
#    'window',
#    'sound',
#    'drumspeople',
#    'could',
#    'not',
#    'believe',
#    'i',
#    'd',
#    'becomerevolutionarie',
#    'waitfor',
#    'head',
#    'silver',
#    'platejust',
#    'puppet',
#    'lonely',
#    'stringoh',
#    'would',
#    'ever',
#    'want',
#    'kingi',
#    'hear',
#    'jerusalem',
#    'bell',
#    'ringingroman',
#    'cavalry',
#    'choir',
#    'singingbe',
#    'mirror',
#    'sword',
#    'shieldmy',
#    'missionary',
#    'foreign',
#    'fieldfor',
#    'reason',
#    'can',
#    'not',
#    'explaini',
#    'know',
#    'saint',
#    'peter',
#    'will',
#    'not',
#    'call',
#    'namenever',
#    'honest',
#    'wordbut',
#    'rule',
#    'worldi',
#    'hear',
#    'jerusalem',
#    'bell',
#    'ringingroman',
#    'cavalry',
#    'choir',
#    'singingbe',
#    'mirror',
#    'sword',
#    'shieldmy',
#    'missionary',
#    'foreign',
#    'fieldfor',
#    'reason',
#    'can',
#    'not',
#    'explaini',
#    'know',
#    'saint',
#    'peter',
#    'will',
#    'not',
#    'call',
#    'namenever',
#    'honest',
#    'wordbut',
#    'rule',
#    'world']},
#  {'filename': 'Paradise',
#   'original_text': 'Almost Paradise achimboda deo nunbusinNal hyanghan neoui sarangi onsesang da gajindeutaeIn my life nae jichin sarme kkumcheoreomDagawajun ni moseubeul eonje kkajina saranghal su itdamyeonNeoui soneul japgoseo sesangeul hyanghae himkkeot sorichyeoHaneureul georeo yaksokhae yeongwonhi ojik neomaneul saranghaeBamhaneul byeolbitgateun uri dulmanui areumdaun kkum ParadiseNeowa hamkkehandamyeon eodideun gal su isseo to the my ParadiseNeoreul irheotdeon sigangwa geuapeum modu daijeobwaIjebuteo sijagiya neowa hamkkeTteonaboneun geoya dallyeoganeun geoya loving you foreverAlmost Paradise taeyangboda deo ttaseuhanNal boneun neoui nunbicheun onsesang da gajindeutaeIn my life nae jichin sarme biccheoreomDagawajun ni sarangeul eonje kkajina ganjikhal su itdamyeonYou are All of my love!You are All of my life!Nae modeungeol georeoseo naneunneoreul saranghae!Jeo pureunbada gateun uri dulmanui areumdaun got ParadiseNeowa hamkkehandamyeon eodideun gal su isseo to the my ParadiseNeoreul irheotdeon sigangwa geuapeum modu daijeobwaIjebuteo sijagiya neowa hamkkeTteonaboneun geoya dallyeoganeun geoya loving you foreverAlmost Paradise achimboda deo nunbusinNal hyanghan neoui sarangi onsesang da gajindeutaeIn my life nae jichin sarme kkumcheoreomDagawajun ni moseubeul eonje kkajina saranghal su itdamyeonCheonsagateun ne misoga gadeukhan uri nagwoneNeomaneul wihan kkotteullo yeongwonhi chaewo dulkkeoyaAlmost Paradise taeyangboda deo ttaseuhanNal boneun neoui nunbicheun onsesang da gajindeutaeIn my life nae jichin sarme biccheoreomDagawajun ni sarangeul eonje kkajina ganjikhal su itdamyeonEonjekkajina saranghal su itdamyeon',
#   'tokens': ['almost',
#    'paradise',
#    'achimboda',
#    'deo',
#    'nunbusinnal',
#    'hyanghan',
#    'neoui',
#    'sarangi',
#    'onsesang',
#    'da',
#    'gajindeutaein',
#    'life',
#    'nae',
#    'jichin',
#    'sarme',
#    'kkumcheoreomdagawajun',
#    'ni',
#    'moseubeul',
#    'eonje',
#    'kkajina',
#    'saranghal',
#    'su',
#    'itdamyeonneoui',
#    'soneul',
#    'japgoseo',
#    'sesangeul',
#    'hyanghae',
#    'himkkeot',
#    'sorichyeohaneureul',
#    'georeo',
#    'yaksokhae',
#    'yeongwonhi',
#    'ojik',
#    'neomaneul',
#    'saranghaebamhaneul',
#    'byeolbitgateun',
#    'uri',
#    'dulmanui',
#    'areumdaun',
#    'kkum',
#    'paradiseneowa',
#    'hamkkehandamyeon',
#    'eodideun',
#    'gal',
#    'su',
#    'isseo',
#    'paradiseneoreul',
#    'irheotdeon',
#    'sigangwa',
#    'geuapeum',
#    'modu',
#    'daijeobwaijebuteo',
#    'sijagiya',
#    'neowa',
#    'hamkketteonaboneun',
#    'geoya',
#    'dallyeoganeun',
#    'geoya',
#    'loving',
#    'foreveralmost',
#    'paradise',
#    'taeyangboda',
#    'deo',
#    'ttaseuhannal',
#    'boneun',
#    'neoui',
#    'nunbicheun',
#    'onsesang',
#    'da',
#    'gajindeutaein',
#    'life',
#    'nae',
#    'jichin',
#    'sarme',
#    'biccheoreomdagawajun',
#    'ni',
#    'sarangeul',
#    'eonje',
#    'kkajina',
#    'ganjikhal',
#    'su',
#    'itdamyeonyou',
#    'loveyou',
#    'lifenae',
#    'modeungeol',
#    'georeoseo',
#    'naneunneoreul',
#    'saranghaejeo',
#    'pureunbada',
#    'gateun',
#    'uri',
#    'dulmanui',
#    'areumdaun',
#    'got',
#    'paradiseneowa',
#    'hamkkehandamyeon',
#    'eodideun',
#    'gal',
#    'su',
#    'isseo',
#    'paradiseneoreul',
#    'irheotdeon',
#    'sigangwa',
#    'geuapeum',
#    'modu',
#    'daijeobwaijebuteo',
#    'sijagiya',
#    'neowa',
#    'hamkketteonaboneun',
#    'geoya',
#    'dallyeoganeun',
#    'geoya',
#    'loving',
#    'foreveralmost',
#    'paradise',
#    'achimboda',
#    'deo',
#    'nunbusinnal',
#    'hyanghan',
#    'neoui',
#    'sarangi',
#    'onsesang',
#    'da',
#    'gajindeutaein',
#    'life',
#    'nae',
#    'jichin',
#    'sarme',
#    'kkumcheoreomdagawajun',
#    'ni',
#    'moseubeul',
#    'eonje',
#    'kkajina',
#    'saranghal',
#    'su',
#    'itdamyeoncheonsagateun',
#    'ne',
#    'misoga',
#    'gadeukhan',
#    'uri',
#    'nagwoneneomaneul',
#    'wihan',
#    'kkotteullo',
#    'yeongwonhi',
#    'chaewo',
#    'dulkkeoyaalmost',
#    'paradise',
#    'taeyangboda',
#    'deo',
#    'ttaseuhannal',
#    'boneun',
#    'neoui',
#    'nunbicheun',
#    'onsesang',
#    'da',
#    'gajindeutaein',
#    'life',
#    'nae',
#    'jichin',
#    'sarme',
#    'biccheoreomdagawajun',
#    'ni',
#    'sarangeul',
#    'eonje',
#    'kkajina',
#    'ganjikhal',
#    'su',
#    'itdamyeoneonjekkajina',
#    'saranghal',
#    'su',
#    'itdamyeon'],
#   'POS': ['ADV',
#    'PROPN',
#    'PROPN',
#    'VERB',
#    'ADJ',
#    'NOUN',
#    'ADJ',
#    'NOUN',
#    'PROPN',
#    'PROPN',
#    'PROPN',
#    'PROPN',
#    'PROPN',
#    'PROPN',
#    'PROPN',
#    'PROPN',
#    'PROPN',
#    'PROPN',
#    'PROPN',
#    'PROPN',
#    'PROPN',
#    'PROPN',
#    'PROPN',
#    'PROPN',
#    'PROPN',
#    'PROPN',
#    'PROPN',
#    'PROPN',
#    'VERB',
#    'PROPN',
#    'PROPN',
#    'PROPN',
#    'PROPN',
#    'PROPN',
#    'PROPN',
#    'PROPN',
#    'PROPN',
#    'PROPN',
#    'PROPN',
#    'PROPN',
#    'PROPN',
#    'PROPN',
#    'PROPN',
#    'PROPN',
#    'PROPN',
#    'PROPN',
#    'PROPN',
#    'PROPN',
#    'PROPN',
#    'PROPN',
#    'PROPN',
#    'PROPN',
#    'PROPN',
#    'PROPN',
#    'PROPN',
#    'PROPN',
#    'PROPN',
#    'PROPN',
#    'VERB',
#    'NOUN',
#    'PROPN',
#    'PROPN',
#    'NOUN',
#    'NOUN',
#    'VERB',
#    'PROPN',
#    'PROPN',
#    'PROPN',
#    'PROPN',
#    'PROPN',
#    'PROPN',
#    'PROPN',
#    'PROPN',
#    'PROPN',
#    'PROPN',
#    'PROPN',
#    'PROPN',
#    'PROPN',
#    'PROPN',
#    'PROPN',
#    'PROPN',
#    'PROPN',
#    'PROPN',
#    'PROPN',
#    'PROPN',
#    'NOUN',
#    'PROPN',
#    'NOUN',
#    'PROPN',
#    'PROPN',
#    'PROPN',
#    'PROPN',
#    'PROPN',
#    'VERB',
#    'PROPN',
#    'PROPN',
#    'PROPN',
#    'PROPN',
#    'PROPN',
#    'PROPN',
#    'PROPN',
#    'PROPN',
#    'PROPN',
#    'PROPN',
#    'PROPN',
#    'PROPN',
#    'PROPN',
#    'PROPN',
#    'PROPN',
#    'PROPN',
#    'PROPN',
#    'PROPN',
#    'VERB',
#    'PROPN',
#    'PROPN',
#    'PROPN',
#    'PROPN',
#    'ADJ',
#    'NOUN',
#    'ADJ',
#    'NOUN',
#    'PROPN',
#    'PROPN',
#    'PROPN',
#    'PROPN',
#    'PROPN',
#    'PROPN',
#    'PROPN',
#    'PROPN',
#    'PROPN',
#    'PROPN',
#    'PROPN',
#    'PROPN',
#    'PROPN',
#    'PROPN',
#    'PROPN',
#    'PROPN',
#    'PROPN',
#    'PROPN',
#    'PROPN',
#    'PROPN',
#    'PROPN',
#    'PROPN',
#    'INTJ',
#    'PROPN',
#    'PROPN',
#    'PROPN',
#    'PROPN',
#    'NOUN',
#    'NOUN',
#    'VERB',
#    'PROPN',
#    'PROPN',
#    'PROPN',
#    'PROPN',
#    'PROPN',
#    'PROPN',
#    'PROPN',
#    'PROPN',
#    'PROPN',
#    'PROPN',
#    'PROPN',
#    'PROPN',
#    'PROPN',
#    'PROPN',
#    'PROPN',
#    'PROPN',
#    'PROPN',
#    'VERB',
#    'PROPN',
#    'NOUN'],
#   'lemmas': ['almost',
#    'paradise',
#    'achimboda',
#    'deo',
#    'nunbusinnal',
#    'hyanghan',
#    'neoui',
#    'sarangi',
#    'onsesang',
#    'da',
#    'gajindeutaein',
#    'life',
#    'nae',
#    'jichin',
#    'sarme',
#    'kkumcheoreomdagawajun',
#    'ni',
#    'moseubeul',
#    'eonje',
#    'kkajina',
#    'saranghal',
#    'su',
#    'itdamyeonneoui',
#    'soneul',
#    'japgoseo',
#    'sesangeul',
#    'hyanghae',
#    'himkkeot',
#    'sorichyeohaneureul',
#    'georeo',
#    'yaksokhae',
#    'yeongwonhi',
#    'ojik',
#    'neomaneul',
#    'saranghaebamhaneul',
#    'byeolbitgateun',
#    'uri',
#    'dulmanui',
#    'areumdaun',
#    'kkum',
#    'paradiseneowa',
#    'hamkkehandamyeon',
#    'eodideun',
#    'gal',
#    'su',
#    'isseo',
#    'paradiseneoreul',
#    'irheotdeon',
#    'sigangwa',
#    'geuapeum',
#    'modu',
#    'daijeobwaijebuteo',
#    'sijagiya',
#    'neowa',
#    'hamkketteonaboneun',
#    'geoya',
#    'dallyeoganeun',
#    'geoya',
#    'love',
#    'foreveralmost',
#    'paradise',
#    'taeyangboda',
#    'deo',
#    'ttaseuhannal',
#    'boneun',
#    'neoui',
#    'nunbicheun',
#    'onsesang',
#    'da',
#    'gajindeutaein',
#    'life',
#    'nae',
#    'jichin',
#    'sarme',
#    'biccheoreomdagawajun',
#    'ni',
#    'sarangeul',
#    'eonje',
#    'kkajina',
#    'ganjikhal',
#    'su',
#    'itdamyeonyou',
#    'loveyou',
#    'lifenae',
#    'modeungeol',
#    'georeoseo',
#    'naneunneoreul',
#    'saranghaejeo',
#    'pureunbada',
#    'gateun',
#    'uri',
#    'dulmanui',
#    'areumdaun',
#    'get',
#    'paradiseneowa',
#    'hamkkehandamyeon',
#    'eodideun',
#    'gal',
#    'su',
#    'isseo',
#    'paradiseneoreul',
#    'irheotdeon',
#    'sigangwa',
#    'geuapeum',
#    'modu',
#    'daijeobwaijebuteo',
#    'sijagiya',
#    'neowa',
#    'hamkketteonaboneun',
#    'geoya',
#    'dallyeoganeun',
#    'geoya',
#    'love',
#    'foreveralmost',
#    'paradise',
#    'achimboda',
#    'deo',
#    'nunbusinnal',
#    'hyanghan',
#    'neoui',
#    'sarangi',
#    'onsesang',
#    'da',
#    'gajindeutaein',
#    'life',
#    'nae',
# ...
#    'ill',
#    'raise',
#    'flagohit',
#    'wa',
#    'wa',
#    'wa',
#    'wa',
#    'waaterfalla',
#    'wa',
#    'wa',
#    'wa',
#    'wa',
#    'waaterfallevery',
#    'tearevery',
#    'tearevery',
#    'teardrop',
#    'waterfallevery',
#    'tearevery',
#    'tearevery',
#    'teardrop',
#    'waterfall']},
#  {'filename': 'Christmas Lights',
#   'original_text': 'Christmas nightAnother fightTears we cried a floodGot all kinds of poison inOf poison in my bloodTook my feetTo Oxford streetTrying to right a wrong"Just walk away", those windows sayBut I can\'t believe she\'s goneWhen you\'re still waiting for the snow to fallIt doesn\'t really feel like Christmas at allUp above candles on air flickerOh they flicker and they flowAnd I\'m up here holding on to all those chandeliers of hopeLike some drunken Elvis singingI go singing out of tuneSinging how I always loved you darlingAnd I always willOh when you\'re still waiting for the snow to fallIt doesn\'t really feel like Christmas at allStill waiting for the snow to fallIt doesn\'t really feel like Christmas at allThose Christmas lightsLight up the streetDown where the sea and city meetMay all your troubles soon be goneOh Christmas lightsKeep shining onThose Christmas lightsLight up the streetMaybe they\'ll bring her back to meThen all my troubles will be goneOh Christmas lightsKeep shining onOh woah oh oh oh oh ohoOh Christmas lightsLight up the streetLight up the fireworks in meMay all your troubles soon be goneThose Christmas lightsKeep shining on',
#   'tokens': ['christmas',
#    'nightanother',
#    'fighttears',
#    'cried',
#    'floodgot',
#    'kinds',
#    'poison',
#    'inof',
#    'poison',
#    'bloodtook',
#    'feetto',
#    'oxford',
#    'streettrying',
#    'right',
#    'wrongjust',
#    'walk',
#    'away',
#    'windows',
#    'saybut',
#    'cant',
#    'believe',
#    'shes',
#    'gonewhen',
#    'youre',
#    'still',
#    'waiting',
#    'snow',
#    'fallit',
#    'doesnt',
#    'really',
#    'feel',
#    'like',
#    'christmas',
#    'allup',
#    'candles',
#    'air',
#    'flickeroh',
#    'flicker',
#    'flowand',
#    'im',
#    'holding',
#    'chandeliers',
#    'hopelike',
#    'drunken',
#    'elvis',
#    'singingi',
#    'go',
#    'singing',
#    'tunesinging',
#    'always',
#    'loved',
#    'darlingand',
#    'always',
#    'willoh',
#    'youre',
#    'still',
#    'waiting',
#    'snow',
#    'fallit',
#    'doesnt',
#    'really',
#    'feel',
#    'like',
#    'christmas',
#    'allstill',
#    'waiting',
#    'snow',
#    'fallit',
#    'doesnt',
#    'really',
#    'feel',
#    'like',
#    'christmas',
#    'allthose',
#    'christmas',
#    'lightslight',
#    'streetdown',
#    'sea',
#    'city',
#    'meetmay',
#    'troubles',
#    'soon',
#    'goneoh',
#    'christmas',
#    'lightskeep',
#    'shining',
#    'onthose',
#    'christmas',
#    'lightslight',
#    'streetmaybe',
#    'theyll',
#    'bring',
#    'back',
#    'methen',
#    'troubles',
#    'goneoh',
#    'christmas',
#    'lightskeep',
#    'shining',
#    'onoh',
#    'woah',
#    'oh',
#    'oh',
#    'oh',
#    'oh',
#    'ohooh',
#    'christmas',
#    'lightslight',
#    'streetlight',
#    'fireworks',
#    'memay',
#    'troubles',
#    'soon',
#    'gonethose',
#    'christmas',
#    'lightskeep',
#    'shining'],
#   'POS': ['PROPN',
#    'ADJ',
#    'NOUN',
#    'VERB',
#    'NOUN',
#    'NOUN',
#    'VERB',
#    'PROPN',
#    'NOUN',
#    'NOUN',
#    'NOUN',
#    'NOUN',
#    'VERB',
#    'ADJ',
#    'NOUN',
#    'VERB',
#    'ADV',
#    'PROPN',
#    'PROPN',
#    'AUX',
#    'PART',
#    'VERB',
#    'PRON',
#    'VERB',
#    'NOUN',
#    'PRON',
#    'AUX',
#    'ADV',
#    'VERB',
#    'NOUN',
#    'VERB',
#    'AUX',
#    'PART',
#    'ADV',
#    'VERB',
#    'ADP',
#    'PROPN',
#    'PROPN',
#    'PROPN',
#    'PROPN',
#    'PROPN',
#    'PROPN',
#    'PROPN',
#    'PRON',
#    'AUX',
#    'VERB',
#    'NOUN',
#    'VERB',
#    'PROPN',
#    'PROPN',
#    'PROPN',
#    'VERB',
#    'VERB',
#    'NOUN',
#    'ADV',
#    'VERB',
#    'ADV',
#    'ADV',
#    'PROPN',
#    'PRON',
#    'AUX',
#    'ADV',
#    'VERB',
#    'NOUN',
#    'VERB',
#    'AUX',
#    'PART',
#    'ADV',
#    'VERB',
#    'ADP',
#    'PROPN',
#    'NOUN',
#    'VERB',
#    'NOUN',
#    'VERB',
#    'AUX',
#    'PART',
#    'ADV',
#    'VERB',
#    'SCONJ',
#    'PROPN',
#    'PROPN',
#    'PROPN',
#    'PROPN',
#    'PROPN',
#    'NOUN',
#    'NOUN',
#    'PROPN',
#    'NOUN',
#    'ADV',
#    'VERB',
#    'PROPN',
#    'NOUN',
#    'VERB',
#    'ADJ',
#    'PROPN',
#    'NOUN',
#    'ADV',
#    'PRON',
#    'AUX',
#    'VERB',
#    'ADV',
#    'NOUN',
#    'NOUN',
#    'VERB',
#    'PROPN',
#    'ADV',
#    'VERB',
#    'NOUN',
#    'PROPN',
#    'INTJ',
#    'INTJ',
#    'INTJ',
#    'INTJ',
#    'NOUN',
#    'PROPN',
#    'PROPN',
#    'ADJ',
#    'NOUN',
#    'PROPN',
#    'NOUN',
#    'ADV',
#    'VERB',
#    'PROPN',
#    'NOUN',
#    'VERB'],
#   'lemmas': ['christmas',
#    'nightanother',
#    'fighttear',
#    'cry',
#    'floodgot',
#    'kind',
#    'poison',
#    'inof',
#    'poison',
#    'bloodtook',
#    'feetto',
#    'oxford',
#    'streettrye',
#    'right',
#    'wrongjust',
#    'walk',
#    'away',
#    'windows',
#    'saybut',
#    'can',
#    'not',
#    'believe',
#    'she',
#    's',
#    'gonewhen',
#    'you',
#    're',
#    'still',
#    'wait',
#    'snow',
#    'fallit',
#    'do',
#    'not',
#    'really',
#    'feel',
#    'like',
#    'christmas',
#    'allup',
#    'candles',
#    'air',
#    'flickeroh',
#    'flicker',
#    'flowand',
#    'I',
#    'm',
#    'hold',
#    'chandelier',
#    'hopelike',
#    'drunken',
#    'elvis',
#    'singingi',
#    'go',
#    'singe',
#    'tunesinging',
#    'always',
#    'love',
#    'darlingand',
#    'always',
#    'willoh',
#    'you',
#    're',
#    'still',
#    'wait',
#    'snow',
#    'fallit',
#    'do',
#    'not',
#    'really',
#    'feel',
#    'like',
#    'christmas',
#    'allstill',
#    'wait',
#    'snow',
#    'fallit',
#    'do',
#    'not',
#    'really',
#    'feel',
#    'like',
#    'christmas',
#    'allthose',
#    'christmas',
#    'lightslight',
#    'streetdown',
#    'sea',
#    'city',
#    'meetmay',
#    'trouble',
#    'soon',
#    'goneoh',
#    'christmas',
#    'lightskeep',
#    'shine',
#    'onthose',
#    'christmas',
#    'lightslight',
#    'streetmaybe',
#    'they',
#    'll',
#    'bring',
#    'back',
#    'methen',
#    'trouble',
#    'goneoh',
#    'christmas',
#    'lightskeep',
#    'shine',
#    'onoh',
#    'woah',
#    'oh',
#    'oh',
#    'oh',
#    'oh',
#    'ohooh',
#    'christmas',
#    'lightslight',
#    'streetlight',
#    'firework',
#    'memay',
#    'trouble',
#    'soon',
#    'gonethose',
#    'christmas',
#    'lightskeep',
#    'shine']},
#  {'filename': 'Fix You',
#   'original_text': "When you try your best, but you don't succeedWhen you get what you want, but not what you needWhen you feel so tired, but you can't sleepStuck in reverseAnd the tears come streaming down your faceWhen you lose something you can't replaceWhen you love someone but it goes to wasteCould it be worse?Lights will guide you home,And ignite your bones,And I will try to fix you,High up above or down belowWhen you're too in love to let it goBut if you never try you'll never knowJust what you're worthLights will guide you homeAnd ignite your bonesAnd I will try to fix youTears stream down your faceWhen you lose something you cannot replaceTears stream down your faceAnd ITears stream down your faceI promise you I will learn from my mistakesTears stream down your faceAnd ILights will guide you homeAnd ignite your bonesAnd I will try to fix you",
#   'tokens': ['try',
#    'best',
#    'dont',
#    'succeedwhen',
#    'get',
#    'want',
#    'needwhen',
#    'feel',
#    'tired',
#    'cant',
#    'sleepstuck',
#    'reverseand',
#    'tears',
#    'come',
#    'streaming',
#    'facewhen',
#    'lose',
#    'something',
#    'cant',
#    'replacewhen',
#    'love',
#    'someone',
#    'goes',
#    'wastecould',
#    'worselights',
#    'guide',
#    'homeand',
#    'ignite',
#    'bonesand',
#    'try',
#    'fix',
#    'youhigh',
#    'belowwhen',
#    'youre',
#    'love',
#    'let',
#    'gobut',
#    'never',
#    'try',
#    'youll',
#    'never',
#    'knowjust',
#    'youre',
#    'worthlights',
#    'guide',
#    'homeand',
#    'ignite',
#    'bonesand',
#    'try',
#    'fix',
#    'youtears',
#    'stream',
#    'facewhen',
#    'lose',
#    'something',
#    'replacetears',
#    'stream',
#    'faceand',
#    'itears',
#    'stream',
#    'facei',
#    'promise',
#    'learn',
#    'mistakestears',
#    'stream',
#    'faceand',
#    'ilights',
#    'guide',
#    'homeand',
#    'ignite',
#    'bonesand',
#    'try',
#    'fix'],
#   'POS': ['VERB',
#    'ADV',
#    'AUX',
#    'PART',
#    'VERB',
#    'VERB',
#    'VERB',
#    'ADV',
#    'VERB',
#    'ADJ',
#    'AUX',
#    'PART',
#    'VERB',
#    'NOUN',
#    'NOUN',
#    'VERB',
#    'ADJ',
#    'NOUN',
#    'VERB',
#    'PRON',
#    'AUX',
#    'PART',
#    'VERB',
#    'VERB',
#    'PRON',
#    'VERB',
#    'AUX',
#    'NOUN',
#    'VERB',
#    'PROPN',
#    'PROPN',
#    'PROPN',
#    'VERB',
#    'NOUN',
#    'PROPN',
#    'NOUN',
#    'PRON',
#    'AUX',
#    'NOUN',
#    'VERB',
#    'ADV',
#    'ADV',
#    'VERB',
#    'PRON',
#    'AUX',
#    'ADV',
#    'VERB',
#    'PRON',
#    'VERB',
#    'NOUN',
#    'VERB',
#    'PROPN',
#    'PROPN',
#    'PROPN',
#    'VERB',
#    'NOUN',
#    'NOUN',
#    'NOUN',
#    'NOUN',
#    'VERB',
#    'PRON',
#    'NOUN',
#    'VERB',
#    'NOUN',
#    'NOUN',
#    'VERB',
#    'NOUN',
#    'NOUN',
#    'VERB',
#    'NOUN',
#    'VERB',
#    'NOUN',
#    'NOUN',
#    'VERB',
#    'PROPN',
#    'PROPN',
#    'PROPN',
#    'VERB',
#    'VERB'],
#   'lemmas': ['try',
#    'well',
#    'do',
#    'not',
#    'succeedwhen',
#    'get',
#    'want',
#    'needwhen',
#    'feel',
#    'tired',
#    'can',
#    'not',
#    'sleepstuck',
#    'reverseand',
#    'tear',
#    'come',
#    'streaming',
#    'facewhen',
#    'lose',
#    'something',
#    'can',
#    'not',
#    'replacewhen',
#    'love',
#    'someone',
#    'go',
#    'wastecould',
#    'worselight',
#    'guide',
#    'homeand',
#    'ignite',
#    'bonesand',
#    'try',
#    'fix',
#    'youhigh',
#    'belowwhen',
#    'you',
#    're',
#    'love',
#    'let',
#    'gobut',
#    'never',
#    'try',
#    'you',
#    'll',
#    'never',
#    'knowjust',
#    'you',
#    're',
#    'worthlight',
#    'guide',
#    'homeand',
#    'ignite',
#    'bonesand',
#    'try',
#    'fix',
#    'youtear',
#    'stream',
#    'facewhen',
#    'lose',
#    'something',
#    'replacetear',
#    'stream',
#    'faceand',
#    'itear',
#    'stream',
#    'facei',
#    'promise',
#    'learn',
#    'mistakestear',
#    'stream',
#    'faceand',
#    'ilight',
#    'guide',
#    'homeand',
#    'ignite',
#    'bonesand',
#    'try',
#    'fix']},
#  {'filename': 'Hymn for the Weekend',
#   'original_text': "Oh, angel sent from up aboveYou know you make my world light upWhen I was down, when I was hurtYou came to lift me upLife is a drink and loves a drugOh, now I think I must be miles upWhen I was a river dried upYou came to rain a floodAnd said drink from me, drink from meWhen I was so thirstyPour on a symphony, now I just can't get enoughPut your wings on me, wings on meWhen I was so heavyPour on a symphony when I'm low, low, low, lowI, oh I, oh I, got me feeling drunk and highSo high, so highOh I, oh I, oh I, I'm feeling drunk and highSo high, so highOh, angel sent from up aboveI feel you coursing through my bloodLife is a drink and your love'sAbout to make the stars come outPut your wings on me, wings on meWhen I was so heavyPour on a symphony, when I'm low, low, low, lowI, oh I, oh I, got me feeling drunk and highSo high, so highOh I, oh I, oh I, I'm feeling drunk and highSo high, so highI, oh I, oh I, lalala lalalalaSo high, so highI, oh I, oh I, I'm feeling drunk and highSo high, so highLet me shoot across the skyLet me shoot across theLet me shoot across the skyLet me shoot across theLet me shoot across the skyLet me shoot across theLet me shoot across the skyLet me shoot across the",
#   'tokens': ['oh',
#    'angel',
#    'sent',
#    'aboveyou',
#    'know',
#    'make',
#    'world',
#    'light',
#    'upwhen',
#    'hurtyou',
#    'came',
#    'lift',
#    'uplife',
#    'drink',
#    'loves',
#    'drugoh',
#    'think',
#    'must',
#    'miles',
#    'upwhen',
#    'river',
#    'dried',
#    'upyou',
#    'came',
#    'rain',
#    'floodand',
#    'said',
#    'drink',
#    'drink',
#    'mewhen',
#    'thirstypour',
#    'symphony',
#    'cant',
#    'get',
#    'enoughput',
#    'wings',
#    'wings',
#    'mewhen',
#    'heavypour',
#    'symphony',
#    'im',
#    'low',
#    'low',
#    'low',
#    'lowi',
#    'oh',
#    'oh',
#    'got',
#    'feeling',
#    'drunk',
#    'highso',
#    'high',
#    'highoh',
#    'oh',
#    'oh',
#    'im',
#    'feeling',
#    'drunk',
#    'highso',
#    'high',
#    'highoh',
#    'angel',
#    'sent',
#    'abovei',
#    'feel',
#    'coursing',
#    'bloodlife',
#    'drink',
#    'lovesabout',
#    'make',
#    'stars',
#    'come',
#    'output',
#    'wings',
#    'wings',
#    'mewhen',
#    'heavypour',
#    'symphony',
#    'im',
#    'low',
#    'low',
#    'low',
#    'lowi',
#    'oh',
#    'oh',
#    'got',
#    'feeling',
#    'drunk',
#    'highso',
#    'high',
#    'highoh',
#    'oh',
#    'oh',
#    'im',
#    'feeling',
#    'drunk',
#    'highso',
#    'high',
#    'highi',
#    'oh',
#    'oh',
#    'lalala',
#    'lalalalaso',
#    'high',
#    'highi',
#    'oh',
#    'oh',
#    'im',
#    'feeling',
#    'drunk',
#    'highso',
#    'high',
#    'highlet',
#    'shoot',
#    'across',
#    'skylet',
#    'shoot',
#    'across',
#    'thelet',
#    'shoot',
#    'across',
#    'skylet',
#    'shoot',
#    'across',
#    'thelet',
#    'shoot',
#    'across',
#    'skylet',
#    'shoot',
#    'across',
#    'thelet',
#    'shoot',
#    'across',
#    'skylet',
#    'shoot',
#    'across'],
#   'POS': ['INTJ',
#    'NOUN',
#    'VERB',
#    'ADV',
#    'VERB',
#    'VERB',
#    'NOUN',
#    'NOUN',
#    'PROPN',
#    'PROPN',
#    'VERB',
#    'VERB',
#    'NOUN',
#    'NOUN',
#    'VERB',
#    'PROPN',
#    'NOUN',
#    'AUX',
#    'NOUN',
#    'VERB',
#    'NOUN',
#    'VERB',
#    'NOUN',
#    'VERB',
#    'NOUN',
#    'NOUN',
#    'VERB',
#    'NOUN',
#    'VERB',
#    'PROPN',
#    'PROPN',
#    'NOUN',
#    'AUX',
#    'PART',
#    'VERB',
#    'VERB',
#    'NOUN',
#    'NOUN',
#    'PROPN',
#    'INTJ',
#    'NOUN',
#    'PRON',
#    'VERB',
#    'ADJ',
#    'ADJ',
#    'ADJ',
#    'NOUN',
#    'INTJ',
#    'INTJ',
#    'AUX',
#    'VERB',
#    'ADJ',
#    'NOUN',
#    'ADJ',
#    'NOUN',
#    'INTJ',
#    'INTJ',
#    'PRON',
#    'AUX',
#    'VERB',
#    'ADJ',
#    'NOUN',
#    'ADJ',
#    'PROPN',
#    'NOUN',
#    'VERB',
#    'PROPN',
#    'VERB',
#    'VERB',
#    'NOUN',
#    'NOUN',
#    'NOUN',
#    'VERB',
#    'NOUN',
#    'VERB',
#    'NOUN',
#    'NOUN',
#    'NOUN',
#    'PROPN',
#    'INTJ',
#    'NOUN',
#    'PRON',
#    'VERB',
#    'ADJ',
#    'ADJ',
#    'ADJ',
#    'NOUN',
#    'INTJ',
#    'INTJ',
#    'AUX',
#    'VERB',
#    'ADJ',
#    'NOUN',
#    'ADJ',
#    'NOUN',
#    'INTJ',
#    'INTJ',
#    'PRON',
#    'AUX',
#    'VERB',
#    'ADJ',
#    'NOUN',
#    'ADJ',
#    'NOUN',
#    'INTJ',
#    'INTJ',
#    'NOUN',
#    'VERB',
#    'ADJ',
#    'NOUN',
#    'INTJ',
#    'INTJ',
#    'PRON',
#    'AUX',
#    'VERB',
#    'ADJ',
#    'NOUN',
#    'ADJ',
#    'NOUN',
#    'NOUN',
#    'ADP',
#    'NOUN',
#    'NOUN',
#    'ADP',
#    'NOUN',
#    'NOUN',
#    'ADP',
#    'NOUN',
#    'NOUN',
#    'ADP',
#    'NOUN',
#    'NOUN',
#    'ADP',
#    'NOUN',
#    'NOUN',
#    'ADP',
#    'NOUN',
#    'NOUN',
#    'ADP',
#    'NOUN',
#    'NOUN',
#    'ADP'],
#   'lemmas': ['oh',
#    'angel',
#    'send',
#    'aboveyou',
#    'know',
#    'make',
#    'world',
#    'light',
#    'upwhen',
#    'hurtyou',
#    'come',
#    'lift',
#    'uplife',
#    'drink',
#    'love',
#    'drugoh',
#    'think',
#    'must',
#    'mile',
#    'upwhen',
#    'river',
#    'dry',
#    'upyou',
#    'come',
#    'rain',
#    'floodand',
#    'say',
#    'drink',
#    'drink',
#    'mewhen',
#    'thirstypour',
#    'symphony',
#    'can',
#    'not',
#    'get',
#    'enoughput',
#    'wing',
#    'wing',
#    'mewhen',
#    'heavypour',
#    'symphony',
#    'I',
#    'm',
#    'low',
#    'low',
#    'low',
#    'lowi',
#    'oh',
#    'oh',
#    'get',
#    'feel',
#    'drunk',
#    'highso',
#    'high',
#    'highoh',
#    'oh',
#    'oh',
#    'I',
#    'm',
#    'feel',
#    'drunk',
#    'highso',
#    'high',
#    'highoh',
#    'angel',
#    'send',
#    'abovei',
#    'feel',
#    'course',
#    'bloodlife',
#    'drink',
#    'lovesabout',
#    'make',
#    'star',
#    'come',
#    'output',
#    'wing',
#    'wing',
#    'mewhen',
#    'heavypour',
#    'symphony',
#    'I',
#    'm',
#    'low',
#    'low',
#    'low',
#    'lowi',
#    'oh',
#    'oh',
#    'get',
#    'feel',
#    'drunk',
#    'highso',
#    'high',
#    'highoh',
#    'oh',
#    'oh',
#    'I',
#    'm',
#    'feel',
#    'drunk',
#    'highso',
#    'high',
#    'highi',
#    'oh',
#    'oh',
#    'lalala',
#    'lalalalaso',
#    'high',
#    'highi',
#    'oh',
#    'oh',
#    'I',
#    'm',
#    'feel',
#    'drunk',
#    'highso',
#    'high',
#    'highlet',
#    'shoot',
#    'across',
#    'skylet',
#    'shoot',
#    'across',
#    'thelet',
#    'shoot',
#    'across',
#    'skylet',
#    'shoot',
#    'across',
#    'thelet',
#    'shoot',
#    'across',
#    'skylet',
#    'shoot',
#    'across',
#    'thelet',
#    'shoot',
#    'across',
#    'skylet',
#    'shoot',
#    'across']}]

# %% [markdown]
# #### 5. Make the file_data into datafram and export CSV

# %%
df = pd.DataFrame(file_data)

df.to_csv('clean_pos_lemmas_lyrics.csv', index=False)
